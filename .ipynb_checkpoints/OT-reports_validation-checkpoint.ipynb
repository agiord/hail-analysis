# %%
#!/usr/bin/python
#import wradlib as wrl
import pylab as pl
from glob import glob
import warnings
warnings.filterwarnings('ignore')
try:
    get_ipython().magic("matplotlib inline")
except:
    pl.ion()
import numpy as np

import csv
import os
import datetime
import pandas as pd

#shapefile: GIS vector data format (ESRI)
import shapefile as shp  # Requires the pyshp package
import matplotlib
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D
from matplotlib import ticker
import netCDF4 as nc4
from datetime import date,timedelta
import plotly.graph_objs as go
import matplotlib.lines as mlines
import seaborn as sns
import shapely

import importlib
import geopandas as gpd
import xarray as xr
import cartopy.crs as ccrs  # Projections list

import _pickle as pickle

#import external functions (need pip install ipynb)
import ipynb.fs.full.HaileventsFunctions as HF

# %% [markdown]
# # Notebook for validating the filtered and unfiltered datasets vs hail reports
#
# - Upload OT data and hail reports data
# - sea-land mask filter for OT data: retain only land OT detection (which can be verified against observations!)
# - Define spatial and temporal window to check the matching between the two datasets:
#     - spatial window: consider **25km** like in Punge 2017 (yes for the moment)
#     - for ESWD: temporal window **+-1.5h** (in Punge 2017 they used 1h but since I introduced temporal uncertainty aggregating all OTs to 1 hour it is better to consider 1.5h) or 2h around OT detection?
#     - for UNIPOL: large temporal window (**+-5h** ?) due to large uncertainty
# - Build contingency tables and compute scores

# %%
#Folder address containing data:
fold = '/home/ciccuz/phd/KIT/hail_data/'

# %%
# must run the bash command: sshfs -p22 giordano@imk-tss-risk:/hail4/punge/ ./hail4_punge/

#With geopandas: NEW VERSION!
sfg_ita = gpd.read_file(fold + "hail4_punge/geodata/ITA_adm/ITA_adm0.shp", encoding='latin-1')
sfg_deu = gpd.read_file(fold + "hail4_punge/geodata/DEU_adm/DEU_adm0.shp", encoding='latin-1')
sfg_aut = gpd.read_file(fold + "hail4_punge/geodata/AUT_adm/AUT_adm0.shp", encoding='latin-1')
sfg_che = gpd.read_file(fold + "hail4_punge/geodata/CHE_adm/CHE_adm0.shp", encoding='latin-1')
sfg_cro = gpd.read_file(fold + "hail4_punge/geodata/Croatia/mj788hg8036.shp", encoding='latin-1')
sfg_slo = gpd.read_file(fold + "hail4_punge/geodata/Slovenia/gk259nt7452.shp", encoding='latin-1')
sfg_hun = gpd.read_file(fold + "hail4_punge/geodata/Hungary/qh513vs8921.shp", encoding='latin-1')
sfg_alg = gpd.read_file(fold + "hail4_punge/geodata/algeria/rt767cn2098.shp", encoding='latin-1')
sfg_tun = gpd.read_file(fold + "hail4_punge/geodata/tunisia/TUN_adm0.shp", encoding='latin-1')
sfg_bos = gpd.read_file(fold + "hail4_punge/geodata/bosnia/bt512fj0408.shp", encoding='latin-1')
sfg_fra = gpd.read_file(fold + "hail4_punge/geodata/france/dw125xh0996.shp", encoding='latin-1')
sfg_mon = gpd.read_file(fold + "hail4_punge/geodata/montenegro/MNE_adm0.shp", encoding='latin-1')
sfg_cze = gpd.read_file(fold + "hail4_punge/geodata/czech/CZE_adm0.shp", encoding='latin-1')
sfg_svk = gpd.read_file(fold + "hail4_punge/geodata/slovakia/SVK_adm0.shp", encoding='latin-1')


#lat/lon coords to cover the whole SPHERA domain:
lonmin=6; lonmax=19; latmin=35; latmax=49
latplot=[latmin,latmax]; lonplot=[lonmin,lonmax]

#maps limits whole SPHERA domain
x_lim=lonplot
y_lim=latplot


#shapefile in vector form for considering multiple geographic shapefiles
sf_geo = [sfg_ita, sfg_aut, sfg_deu, sfg_che, sfg_cro, sfg_slo, sfg_hun, sfg_alg, sfg_tun, sfg_fra, sfg_bos,
          sfg_mon, sfg_cze, sfg_svk]

hhmin=0; hhmax=23

# %%
#Read and store cities and their features to be used in the maps:
clonsel, clatsel, csizesel, cnamesel, ckindsel = HF.HF_cities(latmin,latmax,lonmin,lonmax)

# %% [markdown]
# ### - Upload data

# %%
#Read ESWD hail report data: store lat, lon, hail size and datetime, and retain only data in the selected area/time
df_eswd = pd.read_csv(fold + 'hail4_punge/ESWD/ESWD_HAIL_19790101-20200531_v1_6.csv')   #Swabian Jura 2013
    
eswd_df = pd.DataFrame(columns=['datetime','lat','lon','size','QC_level'])
eswd_df['datetime'] = pd.to_datetime(df_eswd['TIME_EVENT'])
eswd_df['lat'] = df_eswd['LATITUDE']
eswd_df['lon'] = df_eswd['LONGITUDE']
eswd_df['size'] = df_eswd['MAX_HAIL_DIAMETER']
eswd_df['QC_level'] = df_eswd['QC_LEVEL']

eswd_df = eswd_df.sort_values(by='datetime').reset_index(drop=True)

#try:retain only data in the selected day and year and within hhmin and hhmax, as well as within latmin,latmax and lonmin,lonmax
eswd_df_years = eswd_df.datetime.apply(lambda x: x.year)
eswd_df_months = eswd_df.datetime.apply(lambda x: x.month)
eswd_df_days = eswd_df.datetime.apply(lambda x: x.day)
eswd_df_hours = eswd_df.datetime.apply(lambda x: x.hour)

eswd_df_sel = eswd_df.loc[(eswd_df_years >= 2016) & (eswd_df_years <= 2018) & (eswd_df_months >= 4)   #(eswd_df_years >= 1995) &
                         & (eswd_df_months <= 10)]
eswd_df_sel = eswd_df_sel.loc[(eswd_df_sel.lat >= latmin) & (eswd_df_sel.lat <= latmax)]
eswd = eswd_df_sel.loc[(eswd_df_sel.lon >= lonmin) & (eswd_df_sel.lon <= lonmax)].reset_index(drop=True)

eswd = gpd.GeoDataFrame(eswd, geometry=gpd.points_from_xy(eswd.lon, eswd.lat)) 

eswd
# Out:
#                 datetime     lat     lon  size QC_level  \
# 0    2016-04-06 15:55:00  46.993  13.150   NaN     QC0+
# 1    2016-04-07 06:30:00  45.815   9.571   NaN      QC1
# 2    2016-04-07 19:20:00  46.167   8.800   2.0      QC1
# 3    2016-04-08 04:05:00  48.350  17.567   2.0     QC0+
# 4    2016-04-08 14:30:00  45.117   7.308   NaN      QC1
# ...                  ...     ...     ...   ...      ...
# 1391 2018-10-01 15:30:00  43.433   6.733   NaN     QC0+
# 1392 2018-10-07 12:00:00  40.158  18.292   NaN     QC0+
# 1393 2018-10-21 16:00:00  42.142  12.541   3.0     QC0+
# 1394 2018-10-21 18:00:00  41.888  12.565   NaN     QC0+
# 1395 2018-10-29 06:40:00  40.559   8.318   5.0      QC1
#
#                        geometry
# 0     POINT (13.15000 46.99300)
# 1      POINT (9.57100 45.81500)
# 2      POINT (8.80000 46.16700)
# 3     POINT (17.56700 48.35000)
# 4      POINT (7.30800 45.11700)
# ...                         ...
# 1391   POINT (6.73300 43.43300)
# ...

# %%
#Read UNIPOL insurance data
df_unipol = pd.read_csv(fold + 'data/ESWD_insurance/Insurance_ESSL_Italy_data/original_ungridded_data/UNIPOL/Estrazione_SINISTRI_GRANDINE_E_VENTO_ITALIA_DateLatLon.csv')

#retain only data within the period considered
dfu_ev = pd.DataFrame()
dfu_ev = df_unipol.loc[(df_unipol.year >= 2016) & (df_unipol.year <= 2018) &
                      (df_unipol.month >= 4) & (df_unipol.month <= 10)].reset_index(drop=True)

#save date lat lon data in arrays
u_ev = pd.DataFrame(columns=['datetime','lon','lat'])
u_ev['datetime'] = pd.to_datetime({'year': dfu_ev['year'],'month':dfu_ev['month'],'day':dfu_ev['day'],'hour':dfu_ev['hour'],
               'minute':dfu_ev['min']})
u_ev['lon'] = np.array(dfu_ev.lon)
u_ev['lat'] = np.array(dfu_ev.lat)

u_ev = u_ev.sort_values(by='datetime').reset_index(drop=True)

u_ev_hours = u_ev.datetime.apply(lambda x: x.hour)

unipol = u_ev.loc[(u_ev.lat >= latmin) & (u_ev.lat <= latmax)]
unipol = unipol.loc[(unipol.lon >= lonmin) & (unipol.lon <= lonmax)].reset_index(drop=True)

unipol = gpd.GeoDataFrame(unipol, geometry=gpd.points_from_xy(unipol.lon, unipol.lat)) 

unipol
# Out:
#                  datetime        lon        lat                   geometry
# 0     2017-04-15 17:00:00   7.893009  45.456619   POINT (7.89301 45.45662)
# 1     2017-04-15 17:06:00   7.679822  45.074093   POINT (7.67982 45.07409)
# 2     2017-04-16 10:00:00  12.029904  44.006611  POINT (12.02990 44.00661)
# 3     2017-04-16 18:30:00  11.477947  44.430923  POINT (11.47795 44.43092)
# 4     2017-04-17 00:01:00  11.309953  44.778538  POINT (11.30995 44.77854)
# ...                   ...        ...        ...                        ...
# 27215 2018-10-31 00:01:00   8.742714  45.435177   POINT (8.74271 45.43518)
# 27216 2018-10-31 09:00:00   9.199469  44.312763   POINT (9.19947 44.31276)
# 27217 2018-10-31 10:46:00  14.508273  40.781990  POINT (14.50827 40.78199)
# 27218 2018-10-31 16:00:00   8.852163  44.726948   POINT (8.85216 44.72695)
# 27219 2018-10-31 23:00:00   7.634561  45.402630   POINT (7.63456 45.40263)
#
# [27220 rows x 4 columns]

# %%
#read OT dictionary from external file

eventdays = [
20160407, 20160408, 20160618, 20160624, 20160805, 20160816, 20160829, 20161015,
20170504, 20170514, 20170625, 20170627, 20170628, 20170729, 20170809, 20170810, 20170818,
20180604, 20180723, 20180902, 20180907, 20181007, 20181029]

OT_allEvents = dict()

for eventday in eventdays:

    with open(fold + f'data/OT_filtered_data/tempAgg_3h/OTfilt_{eventday}.txt', "rb") as file:  
        OT_dict = pickle.load(file)
    
    OT_allEvents[eventday] = OT_dict
    
#extract the full sets of all OTs and filtered OTs considering the whole sample of events

all_OTset = gpd.GeoDataFrame(columns=['lon', 'lat', 'time', 'otpmax', 'geometry'])
filt_OTset = gpd.GeoDataFrame(columns=['lon', 'lat', 'time', 'otpmax', 'geometry'])

for eventday in eventdays:
    
    OTday_hours = OT_allEvents[eventday]['ORIGINAL_OTs'].keys()
    
    for hour in OTday_hours:
        
        all_OTset = all_OTset.append(OT_allEvents[eventday]['ORIGINAL_OTs'][hour].reset_index(drop=True))
        filt_OTset = filt_OTset.append(OT_allEvents[eventday]['FILTERED_OTs'][hour].reset_index(drop=True))

filt_OTset['time'] = pd.to_datetime(filt_OTset['time'])    
all_OTset['time'] = pd.to_datetime(all_OTset['time'])    

all_OTset = all_OTset.reset_index(drop=True)
filt_OTset = filt_OTset.reset_index(drop=True)

# %%
all_OTset
# Out:
#             lon        lat                      time  otpmax  \
# 0      8.702145  36.784000 2016-04-07 00:00:00+00:00    0.73
# 1      8.702145  36.748283 2016-04-07 00:00:00+00:00    0.73
# 2      8.914430  37.886143 2016-04-07 01:00:00+00:00    0.63
# 3      9.127715  37.850426 2016-04-07 01:00:00+00:00    0.57
# 4      9.163430  37.849426 2016-04-07 01:00:00+00:00    0.57
# ...         ...        ...                       ...     ...
# 65571  7.566287  39.365429 2018-10-29 23:00:00+00:00    0.58
# 65572  7.460144  39.330711 2018-10-29 23:00:00+00:00    0.58
# 65573  7.494859  39.329712 2018-10-29 23:00:00+00:00    0.58
# 65574  7.530573  39.327713 2018-10-29 23:00:00+00:00    0.58
# 65575  6.531573  38.855431 2018-10-29 23:00:00+00:00    0.51
#
#                        geometry
# 0      POINT (8.70214 36.78400)
# 1      POINT (8.70214 36.74828)
# 2      POINT (8.91443 37.88614)
# 3      POINT (9.12772 37.85043)
# 4      POINT (9.16343 37.84943)
# ...                         ...
# ...

# %%
filt_OTset
# Out:
#             lon        lat                      time  otpmax  \
# 0      9.270573  37.707569 2016-04-07 01:00:00+00:00    0.66
# 1      9.305286  37.706570 2016-04-07 01:00:00+00:00    0.66
# 2      8.771573  37.528000 2016-04-07 01:00:00+00:00    0.67
# 3      8.806287  37.527000 2016-04-07 01:00:00+00:00    0.67
# 4      8.842001  37.527000 2016-04-07 01:00:00+00:00    0.67
# ...         ...        ...                       ...     ...
# 58115  7.530573  39.363430 2018-10-29 23:00:00+00:00    0.58
# 58116  7.566287  39.365429 2018-10-29 23:00:00+00:00    0.58
# 58117  7.460144  39.330711 2018-10-29 23:00:00+00:00    0.58
# 58118  7.494859  39.329712 2018-10-29 23:00:00+00:00    0.58
# 58119  7.530573  39.327713 2018-10-29 23:00:00+00:00    0.58
#
#                        geometry
# 0      POINT (9.27057 37.70757)
# 1      POINT (9.30529 37.70657)
# 2      POINT (8.77157 37.52800)
# 3      POINT (8.80629 37.52700)
# 4      POINT (8.84200 37.52700)
# ...                         ...
# ...

# %% [markdown]
# ### - Sea-land mask: retain only OTs over land (that can be verified against observations)

# %%
sfg_land = gpd.read_file(fold + "hail4_punge/geodata/Land/ne_10m_land.shp", encoding='latin-1')

# %%
filt_OTset_land = gpd.clip(filt_OTset, sfg_land).sort_index()
all_OTset_land = gpd.clip(all_OTset, sfg_land).sort_index()

# %%
ax = filt_OTset_land.plot(markersize=10, figsize=(12, 8), column='otpmax', cmap='Greens', zorder=4)
 
sfg_land.plot(ax=ax, alpha = 0.5, facecolor = 'grey', lw = 0.5, zorder=3)

ax.set_ylim(y_lim)
ax.set_xlim(x_lim)
# Out:
# (6.0, 19.0)

# %% [markdown]
# During the 23 days of events considered a total of **65576** OTs (with prob >=50%) have been detected, over **LAND** instead **45992**
#
# - After the filtering with **FILTER4h** **58487** OTs remained (meaning that **7089** have been filtered, i.e. approx the **10%**)  Over **LAND**: after filtering **40724** remained (meaning that **5268** have been filtered over land, i.e. **11%**)
#
#
# - With **FILTER3h** instead **58120** OTs remained (meaning that **7456** have been filtered, i.e. 11%). Over **LAND**: after filtering **40556** remained (meaning that **5436** have been filtered over land only, i.e. **12%**)

# %% [markdown]
# ### - Spatial window: build 0.23° box (approx 25km) around every OT detection

# %%
#define dimension of the cell: 0.23° approx 25km boxes
cell_size = 0.23

"""
for Filtered OT dataset
"""
# create the cells in a loop
grid_cells = []

#define every cell from the coordinates their centers represented by each point (x,y) and from the cell_size
for (x,y) in zip(filt_OTset_land.lon, filt_OTset_land.lat):
    
    #print((x,y), (x-cell_size/2, y-cell_size/2, x+cell_size/2, y+cell_size/2) )
    grid_cells.append(shapely.geometry.box(x-cell_size/2, y-cell_size/2, x+cell_size/2, y+cell_size/2))

cell = gpd.GeoDataFrame(grid_cells, columns=['geometry'])
filt_OTset_land['geometry_25km_box'] = cell.values

"""
for Unfiltered OT dataset
"""
# create the cells in a loop
grid_cells = []

#define every cell from the coordinates their centers represented by each point (x,y) and from the cell_size
for (x,y) in zip(all_OTset_land.lon, all_OTset_land.lat):
    
    #print((x,y), (x-cell_size/2, y-cell_size/2, x+cell_size/2, y+cell_size/2) )
    grid_cells.append(shapely.geometry.box(x-cell_size/2, y-cell_size/2, x+cell_size/2, y+cell_size/2))

cell = gpd.GeoDataFrame(grid_cells, columns=['geometry'])
all_OTset_land['geometry_25km_box'] = cell.values

# %%
ax = filt_OTset_land.plot(markersize=10, figsize=(12, 8), column='otpmax', cmap='Greens',zorder=2)

ax.set_ylim(y_lim)
ax.set_xlim(x_lim)
#plt.autoscale(False)

#shapefiles    
for shp in sf_geo:
    shp.plot(ax=ax, alpha = 0.5, facecolor = 'none', lw = 0.5, zorder=3)

cell.plot(ax=ax, facecolor="none", edgecolor='grey');
plt.title('Boxes of 0.23° size built around every OT detection \n Sea-land mask (23 event days)', fontsize=15);

#plt.savefig('/home/ciccuz/phd/KIT/scripts/plots/OT_filter_construction/023boxesOT_land.png', 
#            dpi=300, bbox_inches='tight')

# %% [markdown]
# ### - For each OT occurrence check in the spatio/temporal window around it if an observation is found (separately for ESWD and UNIPOL)

# %% [markdown]
# **Hits**: when in the OT window falls AT LEAST one observation
#
# **False alarms**: when in the OT window no observation is detected
#
# **Misses**: when an observation do not fall in any of the OT window
#
# **Correct negatives**: not possible to calculate them

# %% [markdown]
# ### - Validation with ESWD

# %%
#extract eswd subset during the days of events considered (the one to be compared with not the full one!)
evdays = filt_OTset_land.time.dt.strftime('%Y-%m-%d').unique()
eswd_evdays = eswd[eswd.datetime.dt.strftime('%Y-%m-%d').isin(evdays)]

# %%
#Histogram of hailstorm distribution dep. on the hour of the day in UNIPOL events:
plt.figure(figsize=(8,6)) 

plt.hist(eswd_evdays['datetime'].dt.hour, bins=np.arange(0,24,1),
         facecolor = 'red', edgecolor='black', linewidth=0.5)
pl.locator_params(axis='x', nbins=24)

plt.ylabel('N of reports', fontsize=15)
plt.xlabel('Hour of the day (UTC)', fontsize=15)
plt.title('ESWD reports v. hour of the day distribution during 23 event days', fontsize=15);

# %%
#define which set to consider for validation: filt_ or all_ 
OTset = all_OTset_land#filt_OTset_land

# %%
eswd_HITTED = gpd.GeoDataFrame(columns=eswd.columns)
OTset_HITTING = gpd.GeoDataFrame(columns=OTset.columns)

#loop on OT detections
for OT_ind in OTset.index:
    
    OT = OTset[OTset.index == OT_ind]

    OTyear = int(OT.time.apply(lambda x: x.year))
    OTmonth = int(OT.time.apply(lambda x: x.month))
    OTday = int(OT.time.apply(lambda x: x.day))
    OThour = int(OT.time.apply(lambda x: x.hour))
    
    print(OT_ind)

    #loop on eswd reports
    for eswd_ind in eswd.index:

        #calculate time delta between OT and eswd report:
        tdelta = pd.Timedelta(abs(OT.time.values[0] - eswd.datetime[eswd.index == eswd_ind].values[0]))
        
        #condition: if difference between OT and report timing is smaller than (+-)1.5h keep the report
        if tdelta <= timedelta(minutes=90):
            
            #condition on spatial neighbourhood: if eswd report falls inside OT box:
            if eswd.geometry[eswd_ind].within(OTset.geometry_25km_box[OT_ind]):

                print('Hit!')
                eswd_HITTED = eswd_HITTED.append(eswd[eswd.index == eswd_ind])

                OTset_HITTING = OTset_HITTING.append(OTset[OTset.index == OT_ind])
    
    

"""
ALLA FINE DI TUTTO BISOGNA RIPULARE I DATASET HITTED E HITTING DAI DOPPIONI!
"""
# Out:
# 0
# 1
# 202
# 203
# 204
# 205
# 206
# 207
# 208
# 209
# 210
# 211
# 212
# 213
# 214
# 215
# 216
# 217
# 218
# 219
# 220
# 221
# 222
# 223
# 224
# 225
# 226
# 227
# 228
# 229
# 230
# 231
# 232
# 233
# 234
# 235
# 236
# 237
# 238
# 239
# 240
# 241
# 242
# 243
# 244
# 245
# 246
# 247
# 248
# 249
# 250
# 251
# 252
# 253
# 254
# 255
# 256
# 257
# 258
# 259
# 260
# 261
# 262
# 263
# 264
# 265
# 266
# 267
# 268
# 269
# 270
# 271
# 272
# 273
# 274
# 275
# 276
# 277
# 278
# 279
# 280
# 281
# 282
# 283
# 284
# 285
# 286
# 287
# 288
# 289
# 290
# 291
# 292
# 293
# 294
# 295
# 296
# 297
# 298
# 299
# 300
# 301
# 302
# 303
# 304
# 305
# 306
# 307
# 308
# 309
# 310
# 311
# 312
# 313
# 314
# 315
# 316
# 317
# 318
# 319
# 320
# 321
# 322
# 323
# 324
# 325
# 326
# 327
# 328
# 329
# 330
# 331
# 332
# 333
# 334
# 335
# 336
# 337
# 338
# 339
# 340
# 341
# 342
# 343
# 344
# 345
# 346
# 347
# 348
# 349
# 350
# 351
# 352
# 353
# 354
# 355
# 356
# 357
# 358
# 359
# 360
# 361
# 362
# 363
# 364
# 365
# 366
# ...

# %%
#Clean HITTED and HITTING datasets from duplicates

#eswd: because the same eswd report can be detected in the vicinity of multiple OTs
eswd_HITTED_uniq = eswd_HITTED.drop_duplicates()

#OT: because the same OT can detect multiple eswd reports
OT_HITTING_uniq = OTset_HITTING[~OTset_HITTING.index.duplicated(keep='first')]

# %%
result_filt1_dict = dict()

result_filt1_dict['eswd_ev_sel_HITTED'] = eswd_HITTED
result_filt1_dict['eswd_4plot'] = eswd_HITTED_uniq
result_filt1_dict['OTset_HITTING'] = OTset_HITTING
result_filt1_dict['OT_4plot'] = OT_HITTING_uniq

# %%
#write dictionary to external file
#with open(fold + 'data/OTfilter_validation/OTfilter_validation_eswd/OTunfilteredSet_vs_eswd.txt', 'wb') as file:
#     pickle.dump(result_filt1_dict,file)

# %%
#read dictionary from external file
with open(fold + 'data/OTfilter_validation/OTfilter_validation_eswd/filtOTset_vs_eswd.txt', 'rb') as file:
     filtOTset_valid_eswd = pickle.load(file)
        
with open(fold + 'data/OTfilter_validation/OTfilter_validation_eswd/unfiltOTset_vs_eswd.txt', 'rb') as file:
     allOTset_valid_eswd = pickle.load(file)

# %%
#FILTERED OT SET VALIDATION
filt_eswd_HITTED = filtOTset_valid_eswd['eswd_ev_sel_HITTED']
filt_eswd_HITTED_uniq = filtOTset_valid_eswd['eswd_4plot']
filt_OTset_land_HITTING = filtOTset_valid_eswd['OTset_HITTING']
filt_OTset_land_HITTING_uniq = filtOTset_valid_eswd['OT_4plot']

#UNFILTERED OT SET VALIDATION
unfilt_eswd_HITTED = allOTset_valid_eswd['eswd_ev_sel_HITTED']
unfilt_eswd_HITTED_uniq = allOTset_valid_eswd['eswd_4plot']
unfilt_OTset_land_HITTING = allOTset_valid_eswd['OTset_HITTING']
unfilt_OTset_land_HITTING_uniq = allOTset_valid_eswd['OT_4plot']

# %% [markdown]
# #### - Fraction of eswd events hitted by filtered OTs:

# %%
len(eswd_HITTED_uniq)/len(eswd_evdays)
# Out:
# 0.8313253012048193

# %% [markdown]
# #### - Fraction of missed eswd events by filtered OTs:

# %%
#missed eswd events:
eswd_MISSED = eswd_evdays[-eswd_evdays.datetime.isin(eswd_HITTED_uniq.datetime)]
len(eswd_MISSED)/len(eswd_evdays)
# Out:
# 0.1686746987951807

# %% [markdown]
# #### - Fraction of filtered OTs hitting at least 1 eswd report

# %%
len(filt_OTset_land_HITTING_uniq)/len(filt_OTset_land)
# Out:
# 0.03363250813689713

# %% [markdown]
# #### - Fraction of filtered OTs missing eswd reports

# %%
filt_OTset_land_MISSING = filt_OTset_land[~filt_OTset_land.index.isin(filt_OTset_land_HITTING_uniq.index)]
len(filt_OTset_land_MISSING)/len(filt_OTset_land)
# Out:
# 0.9663674918631029

# %% [markdown]
# #### - Fraction of UNFILTERED OTs hitting at least 1 eswd report

# %%
len(unfilt_OTset_land_HITTING_uniq)/len(all_OTset_land)
# Out:
# 0.03180987997912681

# %% [markdown]
# #### - Fraction of UNFILTERED OTs missing eswd reports

# %%
unfilt_OTset_land_MISSING = all_OTset_land[~all_OTset_land.index.isin(unfilt_OTset_land_HITTING_uniq.index)]
len(unfilt_OTset_land_MISSING)/len(all_OTset_land)
# Out:
# 0.9681901200208732

# %%
fig, ax = plt.subplots(figsize = (20,12))

plt.ylim(y_lim) #y_lim
plt.xlim(x_lim)  #x_lim

#OTs HITTING:
filt_OTset_land_HITTING_uniq.plot(ax=ax, markersize=10, column='otpmax', color='green',
                                  zorder=2, label='OTs hitting ESWD (1463/45992 = 3.36%)')   #Filt: (1364/40556 = 3.36%)

filt_OTset_land_MISSING.plot(ax=ax, markersize=1, column='otpmax', color='yellow',
                                  zorder=1,alpha=0.3, label='OTs missing ESWD (44529/45992 = 96.63%)')  #Filt: (39192/40556 = 96.63%)

#filt_OTset_land_HITTING_uniq_cells = gpd.GeoDataFrame(columns=['geometry'])
#filt_OTset_land_HITTING_uniq_cells['geometry'] = filt_OTset_land_HITTING_uniq['geometry_25km_box']
#filt_OTset_land_HITTING_uniq_cells.plot(ax=ax, facecolor="none", edgecolor='grey');

#shapefiles    
for shp in sf_geo:
    shp.plot(ax=ax, alpha = 0.5, facecolor = 'none', lw = 0.5, zorder=3)

#ESWD REPORTS:

#HITTED
#divide dataset in subsets with info on size of hail or not:
eswd_HITTED_uniq_NOsize = eswd_HITTED_uniq.loc[np.isnan(eswd_HITTED_uniq['size']) == True].reset_index(drop=True)
eswd_HITTED_uniq_wsize = eswd_HITTED_uniq.loc[np.isnan(eswd_HITTED_uniq['size']) == False].reset_index(drop=True)

pl.scatter(eswd_HITTED_uniq_wsize.lon, eswd_HITTED_uniq_wsize.lat, 15*eswd_HITTED_uniq_wsize['size'],
                c='red',marker="^", edgecolor='k',alpha=0.9,zorder=5, label='ESWD hitted (139/166 = 84%)') #Filt: (138/166 = 83%)
pl.scatter(eswd_HITTED_uniq_NOsize.lon, eswd_HITTED_uniq_NOsize.lat, 35,
                c='red',marker="v", edgecolor='k',alpha=0.9,zorder=5)
#MISSED
#divide dataset in subsets with info on size of hail or not:
eswd_MISSED_NOsize = eswd_MISSED.loc[np.isnan(eswd_MISSED['size']) == True].reset_index(drop=True)
eswd_MISSED_wsize = eswd_MISSED.loc[np.isnan(eswd_MISSED['size']) == False].reset_index(drop=True)

pl.scatter(eswd_MISSED_wsize.lon, eswd_MISSED_wsize.lat, 15*eswd_MISSED_wsize['size'],
           c='blue',marker="^", edgecolor='k',alpha=0.9, zorder=4, label='ESWD missed (27/166 = 16%)') #FIlt: (28/166 = 17%)
pl.scatter(eswd_MISSED_NOsize.lon, eswd_MISSED_NOsize.lat, 35,
           c='blue',marker="v", edgecolor='k',alpha=0.9, zorder=4)   


#cell.plot(ax=ax, facecolor="none", edgecolor='grey');
plt.title('OT UNfiltered set with ESWD hits/misses \n (23 evdays, Spat. window: 25km, Temp. window: ±1.5h)',
          fontsize=15);
plt.legend(loc='best', fontsize=13)

plt.savefig('/home/ciccuz/phd/KIT/scripts/plots/OT_filter_validation_23evdays/OTfilter_eswd_validation.png', 
            dpi=300, bbox_inches='tight')

# %% [markdown]
# ### - Validation with UNIPOL
#
# **ATTENTION**: only 2017 and 2018 years, so must confine analysis to the **15** hail events in these years (withdraw 2016 events), and only over **ITALY!**
#
# - During the 15 event days in 2017-2018, over **LAND** over **ITALY**, a total of **19868** OTs have been detected before filtering, and **18550** remained after filtering
#
# - A total of **27220** UNIPOL reports are reported during 2017-2018, but only **2461** are reported during the 15 event days, of this **643** are issued at 00 (which are most likely due to errors in timing recordings!)
#
# - Due to large temporal uncertainty a temporal window of **+-5h** (for the moment, first test!) is cosidered for unipol reports validation

# %%
#select OT sets in 2017 and 2018 only
all_OTset_land_1718 = all_OTset_land[all_OTset_land.time.dt.year != 2016]
filt_OTset_land_1718 = filt_OTset_land[filt_OTset_land.time.dt.year != 2016]

#select OT sets over Italy only (since UNIPOL data refer only to this region)
all_OTset_land_1718_IT = gpd.clip(all_OTset_land_1718, sfg_ita).sort_index()
filt_OTset_land_1718_IT = gpd.clip(filt_OTset_land_1718, sfg_ita).sort_index()

# %%
#extract unipol subset during the days of events considered (the one to be compared with not the full one!)
evdays_un = filt_OTset_land.time.dt.strftime('%Y-%m-%d').unique()
unipol_evdays = unipol[unipol.datetime.dt.strftime('%Y-%m-%d').isin(evdays_un)]

# %%
#Histogram of hailstorm distribution dep. on the hour of the day in UNIPOL events:
plt.figure(figsize=(8,6)) 

plt.hist(unipol_evdays['datetime'].dt.hour, bins=np.arange(0,24,1),
         facecolor = 'green', edgecolor='black', linewidth=0.5)
pl.locator_params(axis='x', nbins=24)

plt.ylabel('N of reports', fontsize=15)
plt.xlabel('Hour of the day (UTC)', fontsize=15)
plt.title('UNIPOL reports v. hour of the day distribution during 15 event days', fontsize=15);

# %%
#define which set to consider for validation: filt_ or all_ 
OTset = all_OTset_land_1718_IT  #filt_OTset_land

# %%
unipol_HITTED = gpd.GeoDataFrame(columns=unipol_evdays.columns)
OTset_HITTING = gpd.GeoDataFrame(columns=OTset.columns)

#loop on OT detections
for OT_ind in OTset.index:
    
    OT = OTset[OTset.index == OT_ind]

    OTyear = int(OT.time.apply(lambda x: x.year))
    OTmonth = int(OT.time.apply(lambda x: x.month))
    OTday = int(OT.time.apply(lambda x: x.day))
    OThour = int(OT.time.apply(lambda x: x.hour))
    
    print(OT_ind)

    #loop on unipol reports
    for unipol_ind in unipol_evdays.index:

        #calculate time delta between OT and eswd report:
        tdelta = pd.Timedelta(abs(OT.time.values[0] - 
                                  unipol_evdays.datetime[unipol_evdays.index == unipol_ind].values[0]))
        
        #condition: if difference between OT and unipol report timing is smaller than (+-)5h keep the report
        if tdelta <= timedelta(minutes=300):
            
            #condition on spatial neighbourhood: if eswd report falls inside OT box:
            if unipol_evdays.geometry[unipol_ind].within(OTset.geometry_25km_box[OT_ind]):

                print('Hit!')
                unipol_HITTED = unipol_HITTED.append(unipol_evdays[unipol_evdays.index == unipol_ind])

                OTset_HITTING = OTset_HITTING.append(OTset[OTset.index == OT_ind])

"""
ALLA FINE DI TUTTO BISOGNA RIPULARE I DATASET HITTED E HITTING DAI DOPPIONI!
"""
# Out:
# 12764
# 12765
# 12766
# 12808
# 12809
# 12810
# 12811
# 12816
# 12817
# 12821
# 12880
# 12881
# 12882
# 12883
# 12884
# 12885
# 12886
# 12887
# 12888
# 12889
# 12890
# 12891
# 12892
# 12893
# 12894
# 12895
# 12896
# 12897
# 12898
# 12899
# 12900
# 12901
# 12902
# 12903
# 12904
# 12905
# 12906
# 12907
# 12911
# 12912
# 12913
# 12914
# 12915
# 12916
# 12917
# 12918
# 12924
# 12925
# 12931
# 12932
# 12937
# 12948
# 12949
# 12950
# 12954
# 12955
# 12956
# 12957
# 12958
# 12959
# 12960
# 12961
# 12962
# 12998
# 12999
# 13000
# 13004
# 13005
# 13008
# 13009
# 13010
# 13015
# 13031
# 13032
# 13033
# 13034
# 13035
# 13036
# 13037
# 13038
# 13039
# 13040
# 13041
# 13042
# 13043
# 13044
# 13050
# 13051
# 13052
# 13053
# 13054
# 13055
# 13056
# Hit!
# 13057
# Hit!
# 13058
# Hit!
# 13059
# Hit!
# 13060
# 13061
# 13062
# 13071
# Hit!
# 13072
# Hit!
# 13073
# Hit!
# 13074
# Hit!
# 13075
# Hit!
# 13076
# Hit!
# 13077
# Hit!
# 13078
# Hit!
# 13079
# 13080
# 13081
# 13082
# 13083
# 13084
# 13085
# ...

# %%
#Clean HITTED and HITTING datasets from duplicates

#eswd: because the same eswd report can be detected in the vicinity of multiple OTs
unipol_HITTED_uniq = unipol_HITTED.drop_duplicates()

#OT: because the same OT can detect multiple eswd reports
OT_HITTING_uniq = OTset_HITTING[~OTset_HITTING.index.duplicated(keep='first')]

# %%
result_filt1_dict = dict()

result_filt1_dict['unipol_HITTED'] = unipol_HITTED
result_filt1_dict['unipol_HITTED_uniq'] = unipol_HITTED_uniq
result_filt1_dict['OTset_HITTING'] = OTset_HITTING
result_filt1_dict['OT_HITTING_uniq'] = OT_HITTING_uniq

# %%
#write dictionary to external file
with open(fold + 'data/OTfilter_validation/OTfilter_validation_unipol/OTunfilteredSet_vs_unipol.txt', 'wb') as file:
     pickle.dump(result_filt1_dict,file)

# %%
fig, ax = plt.subplots(figsize = (20,12))

plt.ylim(y_lim) #y_lim
plt.xlim(x_lim)  #x_lim

#OTs HITTING:
OT_HITTING_uniq.plot(ax=ax, markersize=10, column='otpmax', color='green',
                                  zorder=2, label='OTs hitting ESWD ()')   #Filt: (1364/40556 = 3.36%)

#filt_OTset_land_MISSING.plot(ax=ax, markersize=1, column='otpmax', color='yellow',
#                                  zorder=1,alpha=0.3, label='OTs missing ESWD (44529/45992 = 96.63%)')  #Filt: (39192/40556 = 96.63%)

#filt_OTset_land_HITTING_uniq_cells = gpd.GeoDataFrame(columns=['geometry'])
#filt_OTset_land_HITTING_uniq_cells['geometry'] = filt_OTset_land_HITTING_uniq['geometry_25km_box']
#filt_OTset_land_HITTING_uniq_cells.plot(ax=ax, facecolor="none", edgecolor='grey');

#shapefiles    
for shp in sf_geo:
    shp.plot(ax=ax, alpha = 0.5, facecolor = 'none', lw = 0.5, zorder=3)

#ESWD REPORTS:

#HITTED
#divide dataset in subsets with info on size of hail or not:
pl.scatter(unipol_HITTED_uniq.lon, unipol_HITTED_uniq.lat, 15,
                c='red',marker="o", edgecolor='k',alpha=0.9,zorder=5, label='UNIPOL hitted ()') #Filt: (138/166 = 83%)


#MISSED
#divide dataset in subsets with info on size of hail or not:
"""
eswd_MISSED_NOsize = eswd_MISSED.loc[np.isnan(eswd_MISSED['size']) == True].reset_index(drop=True)
eswd_MISSED_wsize = eswd_MISSED.loc[np.isnan(eswd_MISSED['size']) == False].reset_index(drop=True)

pl.scatter(eswd_MISSED_wsize.lon, eswd_MISSED_wsize.lat, 15*eswd_MISSED_wsize['size'],
           c='blue',marker="^", edgecolor='k',alpha=0.9, zorder=4, label='ESWD missed (27/166 = 16%)') #FIlt: (28/166 = 17%)
pl.scatter(eswd_MISSED_NOsize.lon, eswd_MISSED_NOsize.lat, 35,
           c='blue',marker="v", edgecolor='k',alpha=0.9, zorder=4)   
"""

#cell.plot(ax=ax, facecolor="none", edgecolor='grey');
plt.title('OT UNfiltered set with ESWD hits/misses \n (23 evdays, Spat. window: 25km, Temp. window: ±1.5h)',
          fontsize=15);
plt.legend(loc='best', fontsize=13)
