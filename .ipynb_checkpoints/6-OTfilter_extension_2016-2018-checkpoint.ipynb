# %%
#!/usr/bin/python
#import wradlib as wrl
import pylab as pl
from glob import glob
import warnings
warnings.filterwarnings('ignore')
try:
    get_ipython().magic("matplotlib inline")
except:
    pl.ion()
import numpy as np

import csv
import os
import datetime
import pandas as pd

#shapefile: GIS vector data format (ESRI)
import shapefile as shp  # Requires the pyshp package
import matplotlib
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D
from matplotlib import ticker
import netCDF4 as nc4
from datetime import date,timedelta
import plotly.graph_objs as go
import matplotlib.lines as mlines
import seaborn as sns
import shapely

import importlib
import geopandas as gpd
import xarray as xr
import cartopy.crs as ccrs  # Projections list

import _pickle as pickle

#import external functions (need pip install ipynb)
import ipynb.fs.full.HaileventsFunctions as HF

# %% [markdown]
# # OT filter extension to period 2016-2018, Apr-Oct
#
# Extend process defined in ```3-OT-reanFilter_test1.ipynb``` to the whole period

# %% [markdown]
# ## - Preliminar setup

# %%
#Preliminar parameters:

#Folder address containing data:
fold = '/home/ciccuz/phd/KIT/hail_data/'

#lat/lon coords to cover the whole SPHERA domain:
lonmin_S=6; lonmax_S=19; latmin_S=35; latmax_S=49
latplot_S=[latmin_S,latmax_S]; lonplot_S=[lonmin_S,lonmax_S]
#maps limits whole SPHERA domain
xlim=lonplot_S
ylim=latplot_S

#Shapefiles with geopandas: NEW VERSION!
sfg_ita = gpd.read_file(fold + "hail4_punge/geodata/ITA_adm/ITA_adm0.shp", encoding='latin-1')
sfg_deu = gpd.read_file(fold + "hail4_punge/geodata/DEU_adm/DEU_adm0.shp", encoding='latin-1')
sfg_aut = gpd.read_file(fold + "hail4_punge/geodata/AUT_adm/AUT_adm0.shp", encoding='latin-1')
sfg_che = gpd.read_file(fold + "hail4_punge/geodata/CHE_adm/CHE_adm0.shp", encoding='latin-1')
sfg_cro = gpd.read_file(fold + "hail4_punge/geodata/Croatia/mj788hg8036.shp", encoding='latin-1')
sfg_slo = gpd.read_file(fold + "hail4_punge/geodata/Slovenia/gk259nt7452.shp", encoding='latin-1')
sfg_hun = gpd.read_file(fold + "hail4_punge/geodata/Hungary/qh513vs8921.shp", encoding='latin-1')
sfg_alg = gpd.read_file(fold + "hail4_punge/geodata/algeria/rt767cn2098.shp", encoding='latin-1')
sfg_tun = gpd.read_file(fold + "hail4_punge/geodata/tunisia/TUN_adm0.shp", encoding='latin-1')
sfg_bos = gpd.read_file(fold + "hail4_punge/geodata/bosnia/bt512fj0408.shp", encoding='latin-1')
sfg_fra = gpd.read_file(fold + "hail4_punge/geodata/france/dw125xh0996.shp", encoding='latin-1')
sfg_mon = gpd.read_file(fold + "hail4_punge/geodata/montenegro/MNE_adm0.shp", encoding='latin-1')
sfg_cze = gpd.read_file(fold + "hail4_punge/geodata/czech/CZE_adm0.shp", encoding='latin-1')
sfg_svk = gpd.read_file(fold + "hail4_punge/geodata/slovakia/SVK_adm0.shp", encoding='latin-1')

#shapefile in vector form for considering multiple geographic shapefiles
sf_geo = [sfg_ita, sfg_aut, sfg_deu, sfg_che, sfg_cro, sfg_slo, sfg_hun, sfg_alg, sfg_tun, sfg_fra, sfg_bos,
          sfg_mon, sfg_cze, sfg_svk]

#store cities for plotting in maps
clonsel, clatsel, csizesel, cnamesel, ckindsel = HF.HF_cities(latmin_S,latmax_S,lonmin_S,lonmax_S)

#read shapefile of SPHERA 10km grid:
sf_sp = gpd.read_file(fold + "data/lampinet/mask/grid_10_49N.shp", encoding='latin-1')

hhmin=0
hhmax=23

# %%
#SETUP THRESHOLDS FOR SPHERA PROXIES (percentiles of param distributions in presence of ESWD report)

#SET WHEN CONSIDERING TEMP WINDOW = 3H,2-98 perc thresholds
#t_CAPE = 505.32
#t_K = 30.2
#t_LI = -1.27
#t_DLS = 7.4
#t_H0 = 4104.5

#SET WHEN CONSIDERING TEMP WINDOW = 3H,5-95 perc thresholds
t_CAPE = 618.42
t_K = 32.5
t_LI = -2.08
t_DLS = 9.25
t_H0 = 4039

# %%
#LIST OF DAYS WITH JULIAN DAY AND DATETIME FORMAT:

#days in 2016: 214 days
days_2016 = [2016092,2016093,2016094,2016095,2016096,2016097,2016098,2016099,2016100,2016101,2016102,2016103,2016104,
        2016105,2016106,2016107,2016108,2016109,2016110,2016111,2016112,2016113,2016114,2016115,2016116,2016117,
        2016118,2016119,2016120,2016121,2016122,2016123,2016124,2016125,2016126,2016127,2016128,2016129,2016130,
        2016131,2016132,2016133,2016134,2016135,2016136,2016137,2016138,2016139,2016140,2016141,2016142,2016143,
        2016144,2016145,2016146,2016147,2016148,2016149,2016150,2016151,2016152,2016153,2016154,2016155,2016156,
        2016157,2016158,2016159,2016160,2016161,2016162,2016163,2016164,2016165,2016166,2016167,2016168,2016169,
        2016170,2016171,2016172,2016173,2016174,2016175,2016176,2016177,2016178,2016179,2016180,2016181,2016182,
        2016183,2016184,2016185,2016186,2016187,2016188,2016189,2016190,2016191,2016192,2016193,2016194,2016195,
        2016196,2016197,2016198,2016199,2016200,2016201,2016202,2016203,2016204,2016205,2016206,2016207,2016208,
        2016209,2016210,2016211,2016212,2016213,2016214,2016215,2016216,2016217,2016218,2016219,2016220,2016221,
        2016222,2016223,2016224,2016225,2016226,2016227,2016228,2016229,2016230,2016231,2016232,2016233,2016234,
        2016235,2016236,2016237,2016238,2016239,2016240,2016241,2016242,2016243,2016244,2016245,2016246,2016247,
        2016248,2016249,2016250,2016251,2016252,2016253,2016254,2016255,2016256,2016257,2016258,2016259,2016260,
        2016261,2016262,2016263,2016264,2016265,2016266,2016267,2016268,2016269,2016270,2016271,2016272,2016273,
        2016274,2016275,2016276,2016277,2016278,2016279,2016280,2016281,2016282,2016283,2016284,2016285,2016286,
        2016287,2016288,2016289,2016290,2016291,2016292,2016293,2016294,2016295,2016296,2016297,2016298,2016299,
        2016300,2016301,2016302,2016303,2016304,2016305]

#days in 2017: missing 1 april (2017091), 213 days
days_2017 = [2017092,2017093,2017094,2017095,2017096,2017097,2017098,2017099,2017100,2017101,2017102,2017103,2017104,
        2017105,2017106,2017107,2017108,2017109,2017110,2017111,2017112,2017113,2017114,2017115,2017116,2017117,
        2017118,2017119,2017120,2017121,2017122,2017123,2017124,2017125,2017126,2017127,2017128,2017129,2017130,
        2017131,2017132,2017133,2017134,2017135,2017136,2017137,2017138,2017139,2017140,2017141,2017142,2017143,
        2017144,2017145,2017146,2017147,2017148,2017149,2017150,2017151,2017152,2017153,2017154,2017155,2017156,
        2017157,2017158,2017159,2017160,2017161,2017162,2017163,2017164,2017165,2017166,2017167,2017168,2017169,
        2017170,2017171,2017172,2017173,2017174,2017175,2017176,2017177,2017178,2017179,2017180,2017181,2017182,
        2017183,2017184,2017185,2017186,2017187,2017188,2017189,2017190,2017191,2017192,2017193,2017194,2017195,
        2017196,2017197,2017198,2017199,2017200,2017201,2017202,2017203,2017204,2017205,2017206,2017207,2017208,
        2017209,2017210,2017211,2017212,2017213,2017214,2017215,2017216,2017217,2017218,2017219,2017220,2017221,
        2017222,2017223,2017224,2017225,2017226,2017227,2017228,2017229,2017230,2017231,2017232,2017233,2017234,
        2017235,2017236,2017237,2017238,2017239,2017240,2017241,2017242,2017243,2017244,2017245,2017246,2017247,
        2017248,2017249,2017250,2017251,2017252,2017253,2017254,2017255,2017256,2017257,2017258,2017259,2017260,
        2017261,2017262,2017263,2017264,2017265,2017266,2017267,2017268,2017269,2017270,2017271,2017272,2017273,
        2017274,2017275,2017276,2017277,2017278,2017279,2017280,2017281,2017282,2017283,2017284,2017285,2017286,
        2017287,2017288,2017289,2017290,2017291,2017292,2017293,2017294,2017295,2017296,2017297,2017298,2017299,
        2017300,2017301,2017302,2017303,2017304]

#days in 2018: missing 1 april (2018091) and 17 june (2018168), 212 days
days_2018 = [2018092,2018093,2018094,2018095,2018096,2018097,2018098,2018099,2018100,2018101,2018102,2018103,2018104,
        2018105,2018106,2018107,2018108,2018109,2018110,2018111,2018112,2018113,2018114,2018115,2018116,2018117,
        2018118,2018119,2018120,2018121,2018122,2018123,2018124,2018125,2018126,2018127,2018128,2018129,2018130,
        2018131,2018132,2018133,2018134,2018135,2018136,2018137,2018138,2018139,2018140,2018141,2018142,2018143,
        2018144,2018145,2018146,2018147,2018148,2018149,2018150,2018151,2018152,2018153,2018154,2018155,2018156,
        2018157,2018158,2018159,2018160,2018161,2018162,2018163,2018164,2018165,2018166,2018167,2018168,2018169,
        2018170,2018171,2018172,2018173,2018174,2018175,2018176,2018177,2018178,2018179,2018180,2018181,2018182,
        2018183,2018184,2018185,2018186,2018187,2018188,2018189,2018190,2018191,2018192,2018193,2018194,2018195,
        2018196,2018197,2018198,2018199,2018200,2018201,2018202,2018203,2018204,2018205,2018206,2018207,2018208,
        2018209,2018210,2018211,2018212,2018213,2018214,2018215,2018216,2018217,2018218,2018219,2018220,2018221,
        2018222,2018223,2018224,2018225,2018226,2018227,2018228,2018229,2018230,2018231,2018232,2018233,2018234,
        2018235,2018236,2018237,2018238,2018239,2018240,2018241,2018242,2018243,2018244,2018245,2018246,2018247,
        2018248,2018249,2018250,2018251,2018252,2018253,2018254,2018255,2018256,2018257,2018258,2018259,2018260,
        2018261,2018262,2018263,2018264,2018265,2018266,2018267,2018268,2018269,2018270,2018271,2018272,2018273,
        2018274,2018275,2018276,2018277,2018278,2018279,2018280,2018281,2018282,2018283,2018284,2018285,2018286,
        2018287,2018288,2018289,2018290,2018291,2018292,2018293,2018294,2018295,2018296,2018297,2018298,2018299,
        2018300,2018301,2018302,2018303,2018304]

# %%
#write dataframes storing julian days and datetimes of OT days:

days_2016_df =pd.DataFrame(index=np.arange(0,len(days_2016),1), columns=['day','dtime'])
days_2017_df =pd.DataFrame(index=np.arange(0,len(days_2017),1), columns=['day','dtime'])
days_2018_df =pd.DataFrame(index=np.arange(0,len(days_2018),1), columns=['day','dtime'])

for day,ind in zip(days_2016,np.arange(0,len(days_2016),1)):
    
    dtime = datetime.datetime.strptime('2016-04-01','%Y-%m-%d') + timedelta(days=int(ind)) 
    
    days_2016_df.iloc[ind]['day'] = day
    days_2016_df.iloc[ind]['dtime'] = dtime    

for day,ind in zip(days_2017,np.arange(0,len(days_2017),1)):
    
    dtime = datetime.datetime.strptime('2017-04-02','%Y-%m-%d') + timedelta(days=int(ind)) 
    
    days_2017_df.iloc[ind]['day'] = day
    days_2017_df.iloc[ind]['dtime'] = dtime    
    
for day,ind in zip(days_2018,np.arange(0,len(days_2018),1)):
    
    dtime = datetime.datetime.strptime('2018-04-02','%Y-%m-%d') + timedelta(days=int(ind)) 
    
    days_2018_df.iloc[ind]['day'] = day
    days_2018_df.iloc[ind]['dtime'] = dtime    

#REMEMBER FOR 2018 MISSING DAY: 2018168 at index 76 (17 jun)

# %% [markdown]
# <span style="color:red"> REMEMBER: for SPHERA the first hour of the first day of april (00) is missing, and also for the first 2 days to extract the "day before" is not possible, must adapt script at the beginning of temporal domain of each year
#
# so the days that must be treated separately are:
#
#     - 2016092,2016093 -> DONE
#
#
# </span>
#
#
# MISSING DAYS (DUE TO SPHERA DATA MISSING, OR OT DATA MISSING):
#
# - ·	2016185 (3-7-2016): missing SPHERA data whole day (but only 32 OTs detected whole day, and no ESWD reports detected)
# - ·	2016186 (4-7-2016): missing SPHERA data only 00UTC (but no OTs detected whole day, and no ESWD reports detected)
# - ·	2016201 (19-7-2016): missing SPHERA data 11-23UTC (but no OTs detected whole day, and no eswd reports detected)

# %%
len(days_2018)
# Out:
# 213

# %%
hhmin=0

d_ind = 1
day = days_2018_df['day'][d_ind]
dtime = days_2018_df['dtime'][d_ind]

dtime,day
# Out:
# (datetime.datetime(2018, 4, 3, 0, 0), 2018093)

# %%
othstart = '0000'
otdir=fold + f'data/OT_SEVIRI_data_2016-2018/{dtime.year}/{day}/';
otpref='NASALARC_MET11_SEVIRI_OTDETECTION_'

# %%
cpclat, cpclon, otpmax, dtmin, ot_timing = HF.HF_OTdata(day,hhmin,hhmin+23,otpref,otdir,othstart)
gdf_OT = HF.HF_OTdata_2_gdf(cpclat,cpclon,otpmax,ot_timing)
gdf_OT
# Out:
# Empty GeoDataFrame
# Columns: [lon, lat, time, otpmax, geometry]
# Index: []

# %%
df_sp = HF.HF_reanProxies_read(dtime)
df_sp
# Out:
#                   datetime box_id      %VV700  AvvGeop500     Kindex  \
# 0      2018-04-02 00:00:00      0   20.000000   -3.593753   8.253723
# 1      2018-04-02 00:00:00      1   26.086956   -0.081493   7.029213
# 2      2018-04-02 00:00:00      2    9.090909   -4.654552   6.146260
# 3      2018-04-02 00:00:00      3   15.000000   -9.455096   6.434350
# 4      2018-04-02 00:00:00      4   30.000000    0.551411   6.540369
# ...                    ...    ...         ...         ...        ...
# 435595 2018-04-02 23:00:00  18145    0.000000    0.000000  21.324911
# 435596 2018-04-02 23:00:00  18146   50.000000    0.000000  20.803299
# 435597 2018-04-02 23:00:00  18147   66.666664    0.000000  20.210083
# 435598 2018-04-02 23:00:00  18148  100.000000    0.000000  19.685974
# 435599 2018-04-02 23:00:00  18149  100.000000    0.000000  19.410828
#
#                LI        DLS          H0   CAPE_MU   CAPE_ML
# 0       10.563971   7.174001  3339.74365  0.021094  0.002344
# 1       11.409803   7.456458  3340.60327  0.080163  0.000000
# 2       10.872461   6.271606  3342.28979  0.154830  0.000000
# 3       10.002958   5.757709  3344.55615  0.008594  0.000000
# 4       10.859722   4.570017  3346.38135  0.003125  0.000000
# ...           ...        ...         ...       ...       ...
# 435595  14.595036  18.111921  2338.70825  0.567708  0.000000
# 435596  14.548812  17.525539  2357.12500  0.464844  0.000000
# 435597  14.349105  16.778809  2409.33325  0.494792  0.000000
# 435598  14.183251  16.195700  2454.83325  0.520833  0.000000
# 435599  14.125960  15.926973  2473.62500  0.500000  0.000000
#
# [434760 rows x 10 columns]

# %% [markdown]
# ### - Single days (when some problems with SPHERA/OT data)

# %%
dtime = dtime-timedelta(days=1)

# %%
dtime
# Out:
# datetime.datetime(2017, 4, 1, 0, 0)

# %%
sp_res = 10  #10km res grid, kept constant

df_sp = pd.DataFrame(columns=["Data","Macroarea","%VV700","AvvGeop500","Kindex","LI","DeepShear",
                              "H0","CAPE_MU","CAPE_ML"])

#read hourly dataframes and aggregate them to form a daily dataframe
for i in np.arange(1,24,1):

    df_temp_SLI_K_AvvGeop_VV700 = pd.read_csv(fold + f'data/SPHERA/sphera_indices_grid{sp_res}km/SLI_K_AvvGeop_VV700/{dtime.year}/ind_'+
                          f'{dtime.year}'+"{:02d}".format(dtime.month)+"{:02d}".format(dtime.day)+"{:02d}".format(i)+'00.csv', 
                          sep=',').drop(columns=["Unnamed: 6"])
    df_temp_CAPE_H0_DLS = pd.read_csv(fold + f'data/SPHERA/sphera_indices_grid{sp_res}km/CAPE_H0_DLS/{dtime.year}/ind_'+
                          f'{dtime.year}'+"{:02d}".format(dtime.month)+"{:02d}".format(dtime.day)+"{:02d}".format(i)+'00_CAPE_H0_DLS.csv', 
                          sep=',').drop(columns=["Unnamed: 6"])

    df_temp = pd.concat([df_temp_SLI_K_AvvGeop_VV700, df_temp_CAPE_H0_DLS[['DeepShear','H0','CAPE_MU','CAPE_ML']]],
                        axis=1, join="inner")
    df_sp = df_sp.append(df_temp, ignore_index=True)

# %%
df_sp = df_sp.rename(columns={'Data' : 'datetime', 'Macroarea' : 'box_id', 'DeepShear' : 'DLS'})

df_sp['datetime'] = pd.to_datetime(df_sp['datetime'], format='%Y%m%d%H')

#drop all rows where one (and so all) of the parameters has huge values >1e38
df_sp = df_sp.drop(df_sp.loc[df_sp.LI > 1e38].index)

#FIX BOX_ID INDEX: make it start from 0 and not 1 otherwise all grid cells are shifted to the left of 1!
df_sp.box_id = df_sp.box_id - 1

# %%
df_sp_Dbefore = df_sp
df_sp_Dbefore
# Out:
#                   datetime box_id      %VV700  AvvGeop500     Kindex  \
# 0      2017-04-01 01:00:00      0   15.000000    4.766196  13.749374
# 1      2017-04-01 01:00:00      1    4.347826   -0.739397  14.340115
# 2      2017-04-01 01:00:00      2    0.000000   19.489500  14.656628
# 3      2017-04-01 01:00:00      3   25.000000   50.090706  14.678198
# 4      2017-04-01 01:00:00      4   40.000000   -7.386747  15.452219
# ...                    ...    ...         ...         ...        ...
# 417445 2017-04-01 23:00:00  18145    0.000000    0.000000  24.069824
# 417446 2017-04-01 23:00:00  18146    0.000000    0.000000  24.179733
# 417447 2017-04-01 23:00:00  18147   33.333332    0.000000  24.435080
# 417448 2017-04-01 23:00:00  18148   33.333332    0.000000  24.661234
# 417449 2017-04-01 23:00:00  18149  100.000000    0.000000  24.798889
#
#               LI        DLS          H0    CAPE_MU   CAPE_ML
# 0       8.043699  19.524601  3158.41870   0.000000  0.000000
# 1       8.187070  19.011076  3157.66309   0.002717  0.000000
# 2       7.584647  19.139179  3158.05103   0.025568  0.000000
# 3       7.222436  17.368835  3142.04370   0.039062  0.000000
# 4       7.659911  15.682042  3140.66260   0.010937  0.000000
# ...          ...        ...         ...        ...       ...
# 417445  2.819385   9.912089  2587.50000  59.156250  0.000000
# 417446  3.008227   9.760023  2592.84375  68.109375  0.000000
# 417447  3.099333   9.452099  2635.87500  80.989586  0.020833
# 417448  3.181852   9.144586  2679.20825  90.781250  1.593750
# 417449  3.238818   8.964868  2698.25000  94.812500  3.718750
#
# [416645 rows x 10 columns]

# %%
#dictionary to contain hourly geodataframes of unfiltered and filtered OTs:
dORIG_gdf_OT_daily = dict()
dFILT_gdf_OT_daily = dict()

#for loop for filtering OTs based on SPHERA rean parameters:
"""
FINAL SET OF FILTER CONSIDERED FOR EXTENSION:
-temporal window: 0-3h
-spatial window: 70km
-thresholds: 5-95%
"""

print(d_ind, day, dtime)

for hh in np.arange(hhmin,hhmax+1,1):
    print(f'hour = {hh}')
    #read original OT data:
    cpclat, cpclon, otpmax, dtmin, ot_timing = HF.HF_OTdata(day,hh,hh+1,otpref,otdir,othstart)
    print('step1 - read OTs')

    #condition: if there aren't OTs detected in the current hour (i.e. len(ot_timing=0)) skip to next hour:
    if len(ot_timing) == 0:
        continue

    #convert to geodataframes
    gdf_OT = HF.HF_OTdata_2_gdf(cpclat,cpclon,otpmax,ot_timing)

    if len(gdf_OT) == 0:
        continue

    dORIG_gdf_OT_daily[gdf_OT['time'].iloc[0]] = gdf_OT
    print('step2 - convert to gdf')

    #condition to exit loop if there are no OTs detected in the last hour:
    if len(gdf_OT) == 0:
        dFILT_gdf_OT_daily[gdf_OT['time'].iloc[0]] = gpd.GeoDataFrame()
        continue
    else:

        #extract SPHERA data aggregated over the last 3 hours before including hhmin
        gdf_sp_3OTh = HF.HF_rean_tAgg_OTh(gdf_OT, df_sp, df_sp_Dbefore, sf_sp)
        print('step3 - temporal aggregation of SPHERA data')

        #extract the spatial windows around every SPHERA cell containing at least 1 OT detection
        dgdf_sp_3OTh_nn = HF.HF_rean_spatWindowOT(gdf_OT, gdf_sp_3OTh)
        print('step4 - spatial neighbourhood of SPHERA data')

        #filter OT data:
        FILT_gdf_OT = HF.HF_OTfilter(gdf_OT, dgdf_sp_3OTh_nn, t_CAPE, t_K, t_LI, t_DLS, t_H0)
        dFILT_gdf_OT_daily[gdf_OT['time'].iloc[0]] = FILT_gdf_OT  #assign time to dataset nested in dictionary

#write dictionaries of geodataframes containing for each hour of the day the original and filtered OTs datasets,
#plus a dataframe of metadata containing the info for each our of filtered OTs and daily amount of:
filt_nonfilt_OTs = dict()

filt_nonfilt_OTs['ORIGINAL_OTs'] = dORIG_gdf_OT_daily
filt_nonfilt_OTs['FILTERED_OTs'] = dFILT_gdf_OT_daily
filt_nonfilt_OTs['metadata'] = pd.DataFrame(index=np.arange(0,24,1),columns=['hour','Filt_OTs','Orig_OTs'])

for ind,hour in zip(np.arange(0,24,1),dFILT_gdf_OT_daily.keys()):

    filt_nonfilt_OTs['metadata'].loc[ind]['hour'] = hour
    filt_nonfilt_OTs['metadata'].loc[ind]['Filt_OTs'] = len(dFILT_gdf_OT_daily[hour])
    filt_nonfilt_OTs['metadata'].loc[ind]['Orig_OTs'] = len(dORIG_gdf_OT_daily[hour])

#write dictionary of filtered/unfiltered OTs to external file
print('WRITE EXTERNAL FILE')
with open(fold + f'data/OT_filtered_data/tempAgg_3h_5-95pThresh/OTfilt_{day}.txt', 'wb') as file:
     pickle.dump(filt_nonfilt_OTs,file)
# Out:
# 0 2017092 2017-04-02 00:00:00
# hour = 0
# step1 - read OTs
# step2 - convert to gdf
# step3 - temporal aggregation of SPHERA data
# step4 - spatial neighbourhood of SPHERA data
# Filtered 1 OTs
# Filtered 3 OTs
# Filtered 3 OTs
# Filtered 2 OTs
# Filtered 2 OTs
# Filtered 1 OTs
# Filtered 5 OTs
# Filtered 6 OTs
# 2 OTs kept!
# Filtered 1 OTs
# Filtered 2 OTs
# Filtered 2 OTs
# Filtered 1 OTs
# Filtered 6 OTs
# Filtered 2 OTs
# Filtered 6 OTs
# Filtered 2 OTs
# Filtered 1 OTs
# Filtered 1 OTs
# Filtered 3 OTs
# Filtered 1 OTs
# Filtered 3 OTs
# Filtered 6 OTs
# Filtered 2 OTs
# Filtered 3 OTs
# Filtered 3 OTs
# Filtered 1 OTs
# Filtered 1 OTs
# hour = 1
# step1 - read OTs
# step2 - convert to gdf
# step3 - temporal aggregation of SPHERA data
# step4 - spatial neighbourhood of SPHERA data
# Filtered 3 OTs
# Filtered 2 OTs
# Filtered 4 OTs
# Filtered 3 OTs
# Filtered 5 OTs
# Filtered 1 OTs
# Filtered 5 OTs
# Filtered 1 OTs
# Filtered 5 OTs
# Filtered 9 OTs
# Filtered 1 OTs
# Filtered 5 OTs
# Filtered 3 OTs
# Filtered 1 OTs
# Filtered 8 OTs
# Filtered 2 OTs
# Filtered 1 OTs
# Filtered 4 OTs
# Filtered 4 OTs
# Filtered 1 OTs
# Filtered 1 OTs
# Filtered 2 OTs
# Filtered 7 OTs
# Filtered 2 OTs
# Filtered 5 OTs
# Filtered 2 OTs
# Filtered 3 OTs
# Filtered 5 OTs
# Filtered 7 OTs
# Filtered 1 OTs
# Filtered 6 OTs
# Filtered 8 OTs
# Filtered 2 OTs
# Filtered 2 OTs
# Filtered 2 OTs
# Filtered 2 OTs
# Filtered 3 OTs
# Filtered 3 OTs
# Filtered 2 OTs
# Filtered 5 OTs
# Filtered 3 OTs
# Filtered 2 OTs
# hour = 2
# step1 - read OTs
# step2 - convert to gdf
# step3 - temporal aggregation of SPHERA data
# step4 - spatial neighbourhood of SPHERA data
# Filtered 1 OTs
# Filtered 3 OTs
# Filtered 1 OTs
# Filtered 2 OTs
# Filtered 3 OTs
# Filtered 6 OTs
# Filtered 2 OTs
# Filtered 1 OTs
# Filtered 1 OTs
# Filtered 4 OTs
# Filtered 2 OTs
# Filtered 1 OTs
# Filtered 1 OTs
# Filtered 3 OTs
# Filtered 2 OTs
# Filtered 2 OTs
# Filtered 2 OTs
# Filtered 1 OTs
# Filtered 2 OTs
# Filtered 2 OTs
# Filtered 2 OTs
# Filtered 1 OTs
# Filtered 1 OTs
# Filtered 1 OTs
# Filtered 2 OTs
# Filtered 2 OTs
# Filtered 2 OTs
# hour = 3
# step1 - read OTs
# step2 - convert to gdf
# step3 - temporal aggregation of SPHERA data
# step4 - spatial neighbourhood of SPHERA data
# Filtered 3 OTs
# Filtered 2 OTs
# Filtered 1 OTs
# Filtered 1 OTs
# Filtered 1 OTs
# Filtered 2 OTs
# Filtered 3 OTs
# Filtered 1 OTs
# Filtered 2 OTs
# Filtered 1 OTs
# hour = 4
# step1 - read OTs
# step2 - convert to gdf
# step3 - temporal aggregation of SPHERA data
# step4 - spatial neighbourhood of SPHERA data
# Filtered 1 OTs
# Filtered 2 OTs
# Filtered 8 OTs
# Filtered 3 OTs
# Filtered 1 OTs
# Filtered 2 OTs
# Filtered 1 OTs
# Filtered 9 OTs
# Filtered 2 OTs
# Filtered 2 OTs
# Filtered 1 OTs
# Filtered 2 OTs
# Filtered 1 OTs
# Filtered 1 OTs
# Filtered 4 OTs
# Filtered 2 OTs
# Filtered 2 OTs
# Filtered 3 OTs
# Filtered 4 OTs
# Filtered 2 OTs
# Filtered 1 OTs
# Filtered 2 OTs
# Filtered 1 OTs
# Filtered 1 OTs
# Filtered 1 OTs
# Filtered 5 OTs
# hour = 5
# step1 - read OTs
# step2 - convert to gdf
# step3 - temporal aggregation of SPHERA data
# step4 - spatial neighbourhood of SPHERA data
# Filtered 3 OTs
# Filtered 2 OTs
# Filtered 1 OTs
# Filtered 1 OTs
# Filtered 4 OTs
# Filtered 1 OTs
# Filtered 2 OTs
# Filtered 3 OTs
# Filtered 1 OTs
# Filtered 2 OTs
# Filtered 4 OTs
# Filtered 1 OTs
# Filtered 3 OTs
# Filtered 5 OTs
# Filtered 5 OTs
# Filtered 2 OTs
# Filtered 1 OTs
# Filtered 2 OTs
# Filtered 2 OTs
# Filtered 1 OTs
# Filtered 1 OTs
# Filtered 6 OTs
# Filtered 2 OTs
# Filtered 2 OTs
# Filtered 4 OTs
# Filtered 1 OTs
# Filtered 1 OTs
# 1 OTs kept!
# Filtered 2 OTs
# Filtered 2 OTs
# Filtered 3 OTs
# Filtered 7 OTs
# Filtered 1 OTs
# Filtered 1 OTs
# Filtered 2 OTs
# Filtered 2 OTs
# Filtered 1 OTs
# Filtered 4 OTs
# hour = 6
# step1 - read OTs
# step2 - convert to gdf
# step3 - temporal aggregation of SPHERA data
# step4 - spatial neighbourhood of SPHERA data
# Filtered 1 OTs
# Filtered 1 OTs
# 1 OTs kept!
# 1 OTs kept!
# Filtered 3 OTs
# Filtered 1 OTs
# Filtered 3 OTs
# Filtered 2 OTs
# Filtered 2 OTs
# Filtered 1 OTs
# Filtered 1 OTs
# Filtered 1 OTs
# Filtered 4 OTs
# Filtered 1 OTs
# Filtered 6 OTs
# Filtered 1 OTs
# Filtered 1 OTs
# Filtered 1 OTs
# Filtered 1 OTs
# Filtered 4 OTs
# Filtered 4 OTs
# Filtered 1 OTs
# 1 OTs kept!
# hour = 7
# step1 - read OTs
# step2 - convert to gdf
# step3 - temporal aggregation of SPHERA data
# step4 - spatial neighbourhood of SPHERA data
# Filtered 1 OTs
# Filtered 1 OTs
# Filtered 4 OTs
# Filtered 1 OTs
# Filtered 1 OTs
# Filtered 2 OTs
# Filtered 3 OTs
# Filtered 1 OTs
# Filtered 1 OTs
# Filtered 2 OTs
# Filtered 1 OTs
# Filtered 1 OTs
# Filtered 2 OTs
# Filtered 1 OTs
# hour = 8
# step1 - read OTs
# step2 - convert to gdf
# step3 - temporal aggregation of SPHERA data
# step4 - spatial neighbourhood of SPHERA data
# Filtered 4 OTs
# Filtered 1 OTs
# Filtered 1 OTs
# Filtered 2 OTs
# 1 OTs kept!
# 1 OTs kept!
# 1 OTs kept!
# hour = 9
# step1 - read OTs
# step2 - convert to gdf
# step3 - temporal aggregation of SPHERA data
# step4 - spatial neighbourhood of SPHERA data
# Filtered 1 OTs
# Filtered 3 OTs
# Filtered 1 OTs
# Filtered 1 OTs
# Filtered 1 OTs
# Filtered 4 OTs
# Filtered 3 OTs
# Filtered 2 OTs
# Filtered 3 OTs
# Filtered 3 OTs
# Filtered 2 OTs
# Filtered 1 OTs
# Filtered 1 OTs
# Filtered 2 OTs
# hour = 10
# step1 - read OTs
# step2 - convert to gdf
# step3 - temporal aggregation of SPHERA data
# step4 - spatial neighbourhood of SPHERA data
# Filtered 5 OTs
# Filtered 4 OTs
# Filtered 1 OTs
# Filtered 2 OTs
# Filtered 2 OTs
# Filtered 1 OTs
# Filtered 4 OTs
# Filtered 1 OTs
# hour = 11
# step1 - read OTs
# step2 - convert to gdf
# step3 - temporal aggregation of SPHERA data
# step4 - spatial neighbourhood of SPHERA data
# 2 OTs kept!
# 1 OTs kept!
# 1 OTs kept!
# 1 OTs kept!
# 1 OTs kept!
# hour = 12
# step1 - read OTs
# step2 - convert to gdf
# step3 - temporal aggregation of SPHERA data
# step4 - spatial neighbourhood of SPHERA data
# 4 OTs kept!
# 2 OTs kept!
# hour = 13
# step1 - read OTs
# step2 - convert to gdf
# step3 - temporal aggregation of SPHERA data
# step4 - spatial neighbourhood of SPHERA data
# 2 OTs kept!
# 4 OTs kept!
# 6 OTs kept!
# 4 OTs kept!
# 4 OTs kept!
# 1 OTs kept!
# 1 OTs kept!
# hour = 14
# step1 - read OTs
# step2 - convert to gdf
# step3 - temporal aggregation of SPHERA data
# step4 - spatial neighbourhood of SPHERA data
# Filtered 1 OTs
# 4 OTs kept!
# 2 OTs kept!
# hour = 15
# step1 - read OTs
# step2 - convert to gdf
# step3 - temporal aggregation of SPHERA data
# step4 - spatial neighbourhood of SPHERA data
# 2 OTs kept!
# 1 OTs kept!
# 1 OTs kept!
# 2 OTs kept!
# 1 OTs kept!
# 1 OTs kept!
# hour = 16
# step1 - read OTs
# hour = 17
# step1 - read OTs
# hour = 18
# step1 - read OTs
# hour = 19
# step1 - read OTs
# hour = 20
# step1 - read OTs
# hour = 21
# step1 - read OTs
# step2 - convert to gdf
# step3 - temporal aggregation of SPHERA data
# step4 - spatial neighbourhood of SPHERA data
# 1 OTs kept!
# hour = 22
# step1 - read OTs
# step2 - convert to gdf
# step3 - temporal aggregation of SPHERA data
# step4 - spatial neighbourhood of SPHERA data
# 1 OTs kept!
# 1 OTs kept!
# Filtered 2 OTs
# Filtered 2 OTs
# 1 OTs kept!
# Filtered 1 OTs
# hour = 23
# step1 - read OTs
# step2 - convert to gdf
# step3 - temporal aggregation of SPHERA data
# step4 - spatial neighbourhood of SPHERA data
# Filtered 3 OTs
# 2 OTs kept!
# 1 OTs kept!
# 4 OTs kept!
# WRITE EXTERNAL FILE

# %% [markdown]
# ### - Loop on several days

# %%
#Loop on days:
for d_ind in np.arange(2,50,1):

    day = days_2018_df['day'][d_ind]
    dtime = days_2018_df['dtime'][d_ind]

    #OT params:
    if dtime.year == 2018:
        otpref='NASALARC_MET11_SEVIRI_OTDETECTION_'     #2018

    else:
        otpref='NASALARC_MET10_SEVIRI_OTDETECTION_'     #2016 2017

    otdir=fold + f'data/OT_SEVIRI_data_2016-2018/{dtime.year}/{day}/';
    othstart = '0000'
    
    #read daily sphera data
    df_sp = HF.HF_reanProxies_read(dtime)
    df_sp_Dbefore = HF.HF_reanProxies_read(dtime-timedelta(days=1)) 

    #dictionary to contain hourly geodataframes of unfiltered and filtered OTs:
    dORIG_gdf_OT_daily = dict()
    dFILT_gdf_OT_daily = dict()

    #for loop for filtering OTs based on SPHERA rean parameters:
    """
    FINAL SET OF FILTER CONSIDERED FOR EXTENSION:
    -temporal window: 0-3h
    -spatial window: 70km
    -thresholds: 5-95%
    """

    print(d_ind, day, dtime)

    for hh in np.arange(hhmin,hhmax+1,1):
        print(f'hour = {hh}')
        #read original OT data:
        cpclat, cpclon, otpmax, dtmin, ot_timing = HF.HF_OTdata(day,hh,hh+1,otpref,otdir,othstart)
        print('step1 - read OTs')

        #condition: if there aren't OTs detected in the current hour (i.e. len(ot_timing=0)) skip to next hour:
        if len(ot_timing) == 0:
            continue

        #convert to geodataframes
        gdf_OT = HF.HF_OTdata_2_gdf(cpclat,cpclon,otpmax,ot_timing)

        if len(gdf_OT) == 0:
            continue

        dORIG_gdf_OT_daily[gdf_OT['time'].iloc[0]] = gdf_OT
        print('step2 - convert to gdf')

        #condition to exit loop if there are no OTs detected in the last hour:
        if len(gdf_OT) == 0:
            dFILT_gdf_OT_daily[gdf_OT['time'].iloc[0]] = gpd.GeoDataFrame()
            continue
        else:

            #extract SPHERA data aggregated over the last 3 hours before including hhmin
            gdf_sp_3OTh = HF.HF_rean_tAgg_OTh(gdf_OT, df_sp, df_sp_Dbefore, sf_sp)
            print('step3 - temporal aggregation of SPHERA data')

            #extract the spatial windows around every SPHERA cell containing at least 1 OT detection
            dgdf_sp_3OTh_nn = HF.HF_rean_spatWindowOT(gdf_OT, gdf_sp_3OTh)
            print('step4 - spatial neighbourhood of SPHERA data')

            #filter OT data:
            FILT_gdf_OT = HF.HF_OTfilter(gdf_OT, dgdf_sp_3OTh_nn, t_CAPE, t_K, t_LI, t_DLS, t_H0)
            dFILT_gdf_OT_daily[gdf_OT['time'].iloc[0]] = FILT_gdf_OT  #assign time to dataset nested in dictionary

    #write dictionaries of geodataframes containing for each hour of the day the original and filtered OTs datasets,
    #plus a dataframe of metadata containing the info for each our of filtered OTs and daily amount of:
    filt_nonfilt_OTs = dict()

    filt_nonfilt_OTs['ORIGINAL_OTs'] = dORIG_gdf_OT_daily
    filt_nonfilt_OTs['FILTERED_OTs'] = dFILT_gdf_OT_daily
    filt_nonfilt_OTs['metadata'] = pd.DataFrame(index=np.arange(0,24,1),columns=['hour','Filt_OTs','Orig_OTs'])

    for ind,hour in zip(np.arange(0,24,1),dFILT_gdf_OT_daily.keys()):

        filt_nonfilt_OTs['metadata'].loc[ind]['hour'] = hour
        filt_nonfilt_OTs['metadata'].loc[ind]['Filt_OTs'] = len(dFILT_gdf_OT_daily[hour])
        filt_nonfilt_OTs['metadata'].loc[ind]['Orig_OTs'] = len(dORIG_gdf_OT_daily[hour])

    #write dictionary of filtered/unfiltered OTs to external file
    print('WRITE EXTERNAL FILE')
    with open(fold + f'data/OT_filtered_data/tempAgg_3h_5-95pThresh/OTfilt_{day}.txt', 'wb') as file:
         pickle.dump(filt_nonfilt_OTs,file)
# Out:
# 2 2018094 2018-04-04 00:00:00
# hour = 0
# step1 - read OTs
# hour = 1
# step1 - read OTs
# hour = 2
# step1 - read OTs
# hour = 3
# step1 - read OTs
# hour = 4
# step1 - read OTs
# hour = 5
# step1 - read OTs
# hour = 6
# step1 - read OTs
# hour = 7
# step1 - read OTs
# hour = 8
# step1 - read OTs
# hour = 9
# step1 - read OTs
# hour = 10
# step1 - read OTs
# hour = 11
# step1 - read OTs
# step2 - convert to gdf
# step3 - temporal aggregation of SPHERA data
# step4 - spatial neighbourhood of SPHERA data
# Filtered 2 OTs
# Filtered 2 OTs
# Filtered 6 OTs
# hour = 12
# step1 - read OTs
# step2 - convert to gdf
# step3 - temporal aggregation of SPHERA data
# step4 - spatial neighbourhood of SPHERA data
# 1 OTs kept!
# 3 OTs kept!
# 1 OTs kept!
# 5 OTs kept!
# hour = 13
# step1 - read OTs
# hour = 14
# step1 - read OTs
# step2 - convert to gdf
# step3 - temporal aggregation of SPHERA data
# step4 - spatial neighbourhood of SPHERA data
# 3 OTs kept!
# 3 OTs kept!
# hour = 15
# step1 - read OTs
# step2 - convert to gdf
# step3 - temporal aggregation of SPHERA data
# step4 - spatial neighbourhood of SPHERA data
# Filtered 1 OTs
# Filtered 4 OTs
# Filtered 6 OTs
# Filtered 2 OTs
# Filtered 1 OTs
# hour = 16
# step1 - read OTs
# step2 - convert to gdf
# step3 - temporal aggregation of SPHERA data
# step4 - spatial neighbourhood of SPHERA data
# Filtered 1 OTs
# Filtered 2 OTs
# Filtered 2 OTs
# Filtered 5 OTs
# Filtered 2 OTs
# Filtered 2 OTs
# Filtered 3 OTs
# Filtered 2 OTs
# Filtered 2 OTs
# Filtered 8 OTs
# Filtered 6 OTs
# Filtered 2 OTs
# Filtered 1 OTs
# Filtered 2 OTs
# Filtered 1 OTs
# Filtered 3 OTs
# 2 OTs kept!
# Filtered 1 OTs
# hour = 17
# step1 - read OTs
# step2 - convert to gdf
# step3 - temporal aggregation of SPHERA data
# step4 - spatial neighbourhood of SPHERA data
# Filtered 4 OTs
# Filtered 2 OTs
# Filtered 1 OTs
# Filtered 2 OTs
# Filtered 2 OTs
# Filtered 2 OTs
# Filtered 1 OTs
# Filtered 2 OTs
# Filtered 2 OTs
# Filtered 1 OTs
# hour = 18
# step1 - read OTs
# step2 - convert to gdf
# step3 - temporal aggregation of SPHERA data
# step4 - spatial neighbourhood of SPHERA data
# Filtered 1 OTs
# Filtered 1 OTs
# Filtered 2 OTs
# Filtered 1 OTs
# hour = 19
# step1 - read OTs
# step2 - convert to gdf
# step3 - temporal aggregation of SPHERA data
# step4 - spatial neighbourhood of SPHERA data
# Filtered 4 OTs
# Filtered 3 OTs
# Filtered 1 OTs
# Filtered 6 OTs
# hour = 20
# step1 - read OTs
# step2 - convert to gdf
# step3 - temporal aggregation of SPHERA data
# step4 - spatial neighbourhood of SPHERA data
# Filtered 5 OTs
# Filtered 1 OTs
# Filtered 4 OTs
# Filtered 7 OTs
# Filtered 4 OTs
# Filtered 1 OTs
# Filtered 1 OTs
# hour = 21
# step1 - read OTs
# step2 - convert to gdf
# step3 - temporal aggregation of SPHERA data
# step4 - spatial neighbourhood of SPHERA data
# Filtered 1 OTs
# Filtered 2 OTs
# Filtered 1 OTs
# Filtered 4 OTs
# Filtered 4 OTs
# Filtered 3 OTs
# hour = 22
# step1 - read OTs
# step2 - convert to gdf
# step3 - temporal aggregation of SPHERA data
# step4 - spatial neighbourhood of SPHERA data
# Filtered 4 OTs
# Filtered 3 OTs
# Filtered 1 OTs
# Filtered 3 OTs
# Filtered 4 OTs
# Filtered 1 OTs
# Filtered 1 OTs
# Filtered 4 OTs
# Filtered 4 OTs
# Filtered 2 OTs
# Filtered 7 OTs
# Filtered 3 OTs
# Filtered 2 OTs
# hour = 23
# step1 - read OTs
# step2 - convert to gdf
# step3 - temporal aggregation of SPHERA data
# step4 - spatial neighbourhood of SPHERA data
# Filtered 2 OTs
# Filtered 4 OTs
# Filtered 1 OTs
# Filtered 4 OTs
# Filtered 1 OTs
# WRITE EXTERNAL FILE
# 3 2018095 2018-04-05 00:00:00
# hour = 0
# step1 - read OTs
# step2 - convert to gdf
# step3 - temporal aggregation of SPHERA data
# step4 - spatial neighbourhood of SPHERA data
# Filtered 3 OTs
# Filtered 3 OTs
# Filtered 3 OTs
# Filtered 4 OTs
# Filtered 1 OTs
# Filtered 1 OTs
# Filtered 8 OTs
# Filtered 7 OTs
# Filtered 2 OTs
# Filtered 1 OTs
# Filtered 2 OTs
# Filtered 1 OTs
# Filtered 1 OTs
# Filtered 3 OTs
# Filtered 6 OTs
# Filtered 3 OTs
# Filtered 2 OTs
# Filtered 2 OTs
# Filtered 7 OTs
# Filtered 2 OTs
# Filtered 2 OTs
# Filtered 7 OTs
# Filtered 2 OTs
# hour = 1
# step1 - read OTs
# step2 - convert to gdf
# step3 - temporal aggregation of SPHERA data
# step4 - spatial neighbourhood of SPHERA data
# Filtered 2 OTs
# Filtered 1 OTs
# Filtered 6 OTs
# Filtered 3 OTs
# Filtered 5 OTs
# Filtered 1 OTs
# Filtered 1 OTs
# Filtered 2 OTs
# Filtered 1 OTs
# Filtered 1 OTs
# hour = 2
# step1 - read OTs
# hour = 3
# step1 - read OTs
# hour = 4
# step1 - read OTs
# hour = 5
# step1 - read OTs
# hour = 6
# step1 - read OTs
# hour = 7
# step1 - read OTs
# hour = 8
# step1 - read OTs
# hour = 9
# step1 - read OTs
# hour = 10
# step1 - read OTs
# hour = 11
# step1 - read OTs
# hour = 12
# step1 - read OTs
# hour = 13
# step1 - read OTs
# step2 - convert to gdf
# step3 - temporal aggregation of SPHERA data
# step4 - spatial neighbourhood of SPHERA data
# 2 OTs kept!
# hour = 14
# step1 - read OTs
# step2 - convert to gdf
# step3 - temporal aggregation of SPHERA data
# step4 - spatial neighbourhood of SPHERA data
# Filtered 2 OTs
# 1 OTs kept!
# Filtered 2 OTs
# 1 OTs kept!
# 1 OTs kept!
# Filtered 1 OTs
# Filtered 1 OTs
# 1 OTs kept!
# 1 OTs kept!
# 1 OTs kept!
# 5 OTs kept!
# 6 OTs kept!
# 4 OTs kept!
# 6 OTs kept!
# 1 OTs kept!
# 2 OTs kept!
# 1 OTs kept!
# 1 OTs kept!
# hour = 15
# step1 - read OTs
# step2 - convert to gdf
# step3 - temporal aggregation of SPHERA data
# step4 - spatial neighbourhood of SPHERA data
# 2 OTs kept!
# 5 OTs kept!
# 3 OTs kept!
# 6 OTs kept!
# 2 OTs kept!
# hour = 16
# step1 - read OTs
# hour = 17
# step1 - read OTs
# hour = 18
# step1 - read OTs
# hour = 19
# step1 - read OTs
# hour = 20
# step1 - read OTs
# hour = 21
# step1 - read OTs
# hour = 22
# step1 - read OTs
# hour = 23
# step1 - read OTs
# WRITE EXTERNAL FILE
# 4 2018096 2018-04-06 00:00:00
# hour = 0
# step1 - read OTs
# hour = 1
# step1 - read OTs
# hour = 2
# step1 - read OTs
# hour = 3
# step1 - read OTs
# hour = 4
# step1 - read OTs
# hour = 5
# step1 - read OTs
# hour = 6
# step1 - read OTs
# hour = 7
# step1 - read OTs
# hour = 8
# step1 - read OTs
# hour = 9
# step1 - read OTs
# hour = 10
# step1 - read OTs
# hour = 11
# step1 - read OTs
# hour = 12
# step1 - read OTs
# hour = 13
# step1 - read OTs
# hour = 14
# step1 - read OTs
# hour = 15
# step1 - read OTs
# hour = 16
# step1 - read OTs
# hour = 17
# step1 - read OTs
# hour = 18
# step1 - read OTs
# hour = 19
# step1 - read OTs
# hour = 20
# step1 - read OTs
# hour = 21
# step1 - read OTs
# hour = 22
# step1 - read OTs
# hour = 23
# step1 - read OTs
# WRITE EXTERNAL FILE
# 5 2018097 2018-04-07 00:00:00
# hour = 0
# step1 - read OTs
# hour = 1
# step1 - read OTs
# hour = 2
# step1 - read OTs
# hour = 3
# step1 - read OTs
# hour = 4
# step1 - read OTs
# hour = 5
# step1 - read OTs
# hour = 6
# step1 - read OTs
# hour = 7
# step1 - read OTs
# hour = 8
# step1 - read OTs
# hour = 9
# step1 - read OTs
# hour = 10
# step1 - read OTs
# hour = 11
# step1 - read OTs
# hour = 12
# step1 - read OTs
# hour = 13
# step1 - read OTs
# hour = 14
# step1 - read OTs
# hour = 15
# step1 - read OTs
# hour = 16
# step1 - read OTs
# hour = 17
# step1 - read OTs
# hour = 18
# step1 - read OTs
# hour = 19
# step1 - read OTs
# hour = 20
# step1 - read OTs
# hour = 21
# step1 - read OTs
# hour = 22
# step1 - read OTs
# hour = 23
# step1 - read OTs
# WRITE EXTERNAL FILE
# 6 2018098 2018-04-08 00:00:00
# hour = 0
# step1 - read OTs
# hour = 1
# step1 - read OTs
# hour = 2
# step1 - read OTs
# hour = 3
# step1 - read OTs
# hour = 4
# step1 - read OTs
# hour = 5
# step1 - read OTs
# hour = 6
# step1 - read OTs
# hour = 7
# step1 - read OTs
# hour = 8
# step1 - read OTs
# hour = 9
# step1 - read OTs
# hour = 10
# step1 - read OTs
# hour = 11
# step1 - read OTs
# hour = 12
# step1 - read OTs
# hour = 13
# step1 - read OTs
# hour = 14
# step1 - read OTs
# step2 - convert to gdf
# step3 - temporal aggregation of SPHERA data
# step4 - spatial neighbourhood of SPHERA data
# Filtered 2 OTs
# Filtered 1 OTs
# Filtered 2 OTs
# hour = 15
# step1 - read OTs
# hour = 16
# step1 - read OTs
# hour = 17
# step1 - read OTs
# hour = 18
# step1 - read OTs
# hour = 19
# step1 - read OTs
# hour = 20
# step1 - read OTs
# hour = 21
# step1 - read OTs
# hour = 22
# step1 - read OTs
# hour = 23
# step1 - read OTs
# WRITE EXTERNAL FILE
# 7 2018099 2018-04-09 00:00:00
# hour = 0
# step1 - read OTs
# hour = 1
# step1 - read OTs
# hour = 2
# step1 - read OTs
# hour = 3
# step1 - read OTs
# step2 - convert to gdf
# step3 - temporal aggregation of SPHERA data
# step4 - spatial neighbourhood of SPHERA data
# Filtered 2 OTs
# Filtered 1 OTs
# Filtered 2 OTs
# Filtered 1 OTs
# Filtered 1 OTs
# hour = 4
# step1 - read OTs
# hour = 5
# step1 - read OTs
# step2 - convert to gdf
# step3 - temporal aggregation of SPHERA data
# step4 - spatial neighbourhood of SPHERA data
# Filtered 4 OTs
# Filtered 1 OTs
# Filtered 1 OTs
# hour = 6
# step1 - read OTs
# hour = 7
# step1 - read OTs
# hour = 8
# step1 - read OTs
# hour = 9
# step1 - read OTs
# step2 - convert to gdf
# step3 - temporal aggregation of SPHERA data
# step4 - spatial neighbourhood of SPHERA data
# Filtered 2 OTs
# Filtered 1 OTs
# hour = 10
# step1 - read OTs
# hour = 11
# step1 - read OTs
# hour = 12
# step1 - read OTs
# hour = 13
# step1 - read OTs
# hour = 14
# step1 - read OTs
# hour = 15
# step1 - read OTs
# hour = 16
# step1 - read OTs
# hour = 17
# step1 - read OTs
# hour = 18
# step1 - read OTs
# hour = 19
# step1 - read OTs
# hour = 20
# step1 - read OTs
# hour = 21
# step1 - read OTs
# hour = 22
# step1 - read OTs
# hour = 23
# step1 - read OTs
# WRITE EXTERNAL FILE
# 8 2018100 2018-04-10 00:00:00
# hour = 0
# step1 - read OTs
# hour = 1
# step1 - read OTs
# step2 - convert to gdf
# step3 - temporal aggregation of SPHERA data
# step4 - spatial neighbourhood of SPHERA data
# hour = 2
# step1 - read OTs
# step2 - convert to gdf
# step3 - temporal aggregation of SPHERA data
# step4 - spatial neighbourhood of SPHERA data
# Filtered 5 OTs
# Filtered 1 OTs
# hour = 3
# step1 - read OTs
# step2 - convert to gdf
# step3 - temporal aggregation of SPHERA data
# step4 - spatial neighbourhood of SPHERA data
# Filtered 8 OTs
# Filtered 2 OTs
# Filtered 1 OTs
# Filtered 2 OTs
# Filtered 1 OTs
# Filtered 2 OTs
# Filtered 4 OTs
# Filtered 2 OTs
# Filtered 6 OTs
# Filtered 2 OTs
# Filtered 1 OTs
# Filtered 5 OTs
# Filtered 3 OTs
# Filtered 3 OTs
# Filtered 1 OTs
# hour = 4
# step1 - read OTs
# step2 - convert to gdf
# step3 - temporal aggregation of SPHERA data
# step4 - spatial neighbourhood of SPHERA data
# Filtered 3 OTs
# Filtered 1 OTs
# Filtered 2 OTs
# Filtered 8 OTs
# Filtered 1 OTs
# Filtered 4 OTs
# Filtered 1 OTs
# Filtered 1 OTs
# Filtered 1 OTs
# Filtered 2 OTs
# Filtered 1 OTs
# Filtered 2 OTs
# Filtered 5 OTs
# Filtered 1 OTs
# Filtered 3 OTs
# Filtered 1 OTs
# Filtered 1 OTs
# Filtered 5 OTs
# Filtered 1 OTs
# Filtered 1 OTs
# Filtered 2 OTs
# Filtered 1 OTs
# Filtered 1 OTs
# Filtered 1 OTs
# hour = 5
# step1 - read OTs
# step2 - convert to gdf
# step3 - temporal aggregation of SPHERA data
# step4 - spatial neighbourhood of SPHERA data
# Filtered 5 OTs
# Filtered 1 OTs
# Filtered 1 OTs
# Filtered 1 OTs
# Filtered 1 OTs
# Filtered 1 OTs
# Filtered 2 OTs
# Filtered 1 OTs
# Filtered 3 OTs
# Filtered 2 OTs
# Filtered 5 OTs
# Filtered 2 OTs
# Filtered 1 OTs
# Filtered 6 OTs
# Filtered 1 OTs
# Filtered 1 OTs
# Filtered 1 OTs
# Filtered 1 OTs
# Filtered 1 OTs
# hour = 6
# step1 - read OTs
# step2 - convert to gdf
# step3 - temporal aggregation of SPHERA data
# step4 - spatial neighbourhood of SPHERA data
# Filtered 1 OTs
# Filtered 1 OTs
# Filtered 4 OTs
# Filtered 1 OTs
# Filtered 1 OTs
# Filtered 4 OTs
# Filtered 1 OTs
# Filtered 5 OTs
# Filtered 8 OTs
# Filtered 1 OTs
# Filtered 1 OTs
# Filtered 1 OTs
# Filtered 3 OTs
# Filtered 1 OTs
# Filtered 1 OTs
# Filtered 1 OTs
# Filtered 1 OTs
# Filtered 1 OTs
# Filtered 1 OTs
# Filtered 1 OTs
# Filtered 3 OTs
# Filtered 2 OTs
# Filtered 1 OTs
# Filtered 1 OTs
# Filtered 1 OTs
# Filtered 1 OTs
# Filtered 4 OTs
# Filtered 2 OTs
# Filtered 1 OTs
# Filtered 1 OTs
# Filtered 2 OTs
# Filtered 1 OTs
# Filtered 1 OTs
# Filtered 1 OTs
# Filtered 2 OTs
# Filtered 3 OTs
# Filtered 3 OTs
# Filtered 1 OTs
# Filtered 1 OTs
# Filtered 2 OTs
# hour = 7
# step1 - read OTs
# step2 - convert to gdf
# step3 - temporal aggregation of SPHERA data
# step4 - spatial neighbourhood of SPHERA data
# Filtered 1 OTs
# Filtered 1 OTs
# Filtered 1 OTs
# Filtered 3 OTs
# Filtered 2 OTs
# Filtered 3 OTs
# Filtered 5 OTs
# Filtered 2 OTs
# Filtered 1 OTs
# Filtered 1 OTs
# Filtered 5 OTs
# Filtered 3 OTs
# Filtered 1 OTs
# Filtered 2 OTs
# Filtered 2 OTs
# Filtered 2 OTs
# Filtered 1 OTs
# Filtered 4 OTs
# Filtered 3 OTs
# Filtered 2 OTs
# Filtered 1 OTs
# Filtered 1 OTs
# Filtered 2 OTs
# Filtered 9 OTs
# Filtered 3 OTs
# Filtered 2 OTs
# hour = 8
# step1 - read OTs
# step2 - convert to gdf
# step3 - temporal aggregation of SPHERA data
# step4 - spatial neighbourhood of SPHERA data
# Filtered 1 OTs
# Filtered 1 OTs
# Filtered 3 OTs
# Filtered 1 OTs
# Filtered 2 OTs
# Filtered 3 OTs
# Filtered 3 OTs
# Filtered 1 OTs
# Filtered 4 OTs
# Filtered 2 OTs
# Filtered 1 OTs
# Filtered 2 OTs
# Filtered 1 OTs
# Filtered 1 OTs
# Filtered 3 OTs
# hour = 9
# step1 - read OTs
# step2 - convert to gdf
# step3 - temporal aggregation of SPHERA data
# step4 - spatial neighbourhood of SPHERA data
# Filtered 2 OTs
# hour = 10
# step1 - read OTs
# hour = 11
# step1 - read OTs
# hour = 12
# step1 - read OTs
# step2 - convert to gdf
# step3 - temporal aggregation of SPHERA data
# step4 - spatial neighbourhood of SPHERA data
# Filtered 1 OTs
# hour = 13
# step1 - read OTs
# hour = 14
# step1 - read OTs
# step2 - convert to gdf
# step3 - temporal aggregation of SPHERA data
# step4 - spatial neighbourhood of SPHERA data
# Filtered 1 OTs
# Filtered 2 OTs
# Filtered 1 OTs
# hour = 15
# step1 - read OTs
# step2 - convert to gdf
# step3 - temporal aggregation of SPHERA data
# step4 - spatial neighbourhood of SPHERA data
# 2 OTs kept!
# 1 OTs kept!
# Filtered 1 OTs
# Filtered 1 OTs
# hour = 16
# step1 - read OTs
# step2 - convert to gdf
# step3 - temporal aggregation of SPHERA data
# step4 - spatial neighbourhood of SPHERA data
# Filtered 2 OTs
# Filtered 1 OTs
# Filtered 3 OTs
# Filtered 3 OTs
# 2 OTs kept!
# 2 OTs kept!
# 2 OTs kept!
# 4 OTs kept!
# 3 OTs kept!
# 1 OTs kept!
# 2 OTs kept!
# 2 OTs kept!
# 2 OTs kept!
# 6 OTs kept!
# 1 OTs kept!
# 1 OTs kept!
# 1 OTs kept!
# 4 OTs kept!
# 1 OTs kept!
# hour = 17
# step1 - read OTs
# step2 - convert to gdf
# step3 - temporal aggregation of SPHERA data
# step4 - spatial neighbourhood of SPHERA data
# 5 OTs kept!
# 6 OTs kept!
# Filtered 5 OTs
# 3 OTs kept!
# 7 OTs kept!
# 1 OTs kept!
# 2 OTs kept!
# Filtered 1 OTs
# 1 OTs kept!
# 2 OTs kept!
# 1 OTs kept!
# 2 OTs kept!
# 7 OTs kept!
# 4 OTs kept!
# 2 OTs kept!
# Filtered 4 OTs
# Filtered 2 OTs
# Filtered 1 OTs
# hour = 18
# step1 - read OTs
# step2 - convert to gdf
# step3 - temporal aggregation of SPHERA data
# step4 - spatial neighbourhood of SPHERA data
# Filtered 1 OTs
# Filtered 7 OTs
# Filtered 3 OTs
# Filtered 2 OTs
# Filtered 1 OTs
# hour = 19
# step1 - read OTs
# step2 - convert to gdf
# step3 - temporal aggregation of SPHERA data
# step4 - spatial neighbourhood of SPHERA data
# Filtered 1 OTs
# Filtered 1 OTs
# Filtered 1 OTs
# Filtered 2 OTs
# Filtered 6 OTs
# Filtered 1 OTs
# Filtered 3 OTs
# Filtered 2 OTs
# Filtered 1 OTs
# Filtered 1 OTs
# Filtered 1 OTs
# Filtered 2 OTs
# Filtered 3 OTs
# Filtered 4 OTs
# Filtered 2 OTs
# Filtered 1 OTs
# Filtered 1 OTs
# Filtered 1 OTs
# Filtered 3 OTs
# Filtered 2 OTs
# Filtered 3 OTs
# Filtered 5 OTs
# Filtered 2 OTs
# Filtered 2 OTs
# Filtered 1 OTs
# Filtered 1 OTs
# Filtered 1 OTs
# Filtered 2 OTs
# Filtered 1 OTs
# Filtered 1 OTs
# Filtered 1 OTs
# Filtered 1 OTs
# Filtered 2 OTs
# Filtered 4 OTs
# Filtered 1 OTs
# Filtered 3 OTs
# Filtered 3 OTs
# hour = 20
# step1 - read OTs
# step2 - convert to gdf
# step3 - temporal aggregation of SPHERA data
# step4 - spatial neighbourhood of SPHERA data
# Filtered 2 OTs
# Filtered 7 OTs
# Filtered 4 OTs
# Filtered 2 OTs
# Filtered 1 OTs
# Filtered 4 OTs
# Filtered 1 OTs
# Filtered 1 OTs
# Filtered 3 OTs
# Filtered 1 OTs
# Filtered 1 OTs
# Filtered 2 OTs
# Filtered 4 OTs
# Filtered 1 OTs
# Filtered 2 OTs
# Filtered 1 OTs
# Filtered 4 OTs
# Filtered 4 OTs
# Filtered 2 OTs
# Filtered 1 OTs
# Filtered 3 OTs
# Filtered 4 OTs
# Filtered 1 OTs
# Filtered 2 OTs
# Filtered 5 OTs
# Filtered 2 OTs
# Filtered 2 OTs
# Filtered 3 OTs
# Filtered 6 OTs
# Filtered 3 OTs
# Filtered 1 OTs
# Filtered 5 OTs
# Filtered 1 OTs
# Filtered 2 OTs
# Filtered 4 OTs
# hour = 21
# step1 - read OTs
# step2 - convert to gdf
# step3 - temporal aggregation of SPHERA data
# step4 - spatial neighbourhood of SPHERA data
# Filtered 1 OTs
# Filtered 1 OTs
# Filtered 3 OTs
# Filtered 1 OTs
# Filtered 4 OTs
# Filtered 1 OTs
# Filtered 2 OTs
# Filtered 1 OTs
# Filtered 1 OTs
# Filtered 6 OTs
# Filtered 1 OTs
# Filtered 2 OTs
# Filtered 1 OTs
# Filtered 1 OTs
# Filtered 6 OTs
# Filtered 2 OTs
# Filtered 2 OTs
# Filtered 2 OTs
# Filtered 2 OTs
# Filtered 2 OTs
# Filtered 2 OTs
# Filtered 2 OTs
# Filtered 3 OTs
# Filtered 7 OTs
# Filtered 1 OTs
# Filtered 5 OTs
# Filtered 1 OTs
# Filtered 2 OTs
# Filtered 2 OTs
# Filtered 3 OTs
# Filtered 3 OTs
# Filtered 4 OTs
# Filtered 2 OTs
# Filtered 1 OTs
# Filtered 6 OTs
# Filtered 7 OTs
# Filtered 4 OTs
# Filtered 1 OTs
# Filtered 1 OTs
# Filtered 2 OTs
# Filtered 3 OTs
# Filtered 3 OTs
# Filtered 2 OTs
# Filtered 3 OTs
# Filtered 1 OTs
# Filtered 2 OTs
# Filtered 3 OTs
# Filtered 1 OTs
# Filtered 1 OTs
# Filtered 1 OTs
# Filtered 1 OTs
# Filtered 4 OTs
# Filtered 1 OTs
# hour = 22
# step1 - read OTs
# step2 - convert to gdf
# step3 - temporal aggregation of SPHERA data
# step4 - spatial neighbourhood of SPHERA data
# Filtered 1 OTs
# Filtered 1 OTs
# Filtered 7 OTs
# Filtered 5 OTs
# Filtered 5 OTs
# Filtered 3 OTs
# Filtered 3 OTs
# Filtered 2 OTs
# Filtered 2 OTs
# Filtered 2 OTs
# Filtered 1 OTs
# Filtered 1 OTs
# Filtered 6 OTs
# Filtered 3 OTs
# Filtered 8 OTs
# Filtered 7 OTs
# Filtered 3 OTs
# Filtered 5 OTs
# Filtered 2 OTs
# Filtered 2 OTs
# Filtered 3 OTs
# Filtered 6 OTs
# Filtered 2 OTs
# Filtered 2 OTs
# Filtered 2 OTs
# Filtered 6 OTs
# Filtered 1 OTs
# Filtered 4 OTs
# Filtered 2 OTs
# Filtered 1 OTs
# Filtered 5 OTs
# Filtered 2 OTs
# Filtered 1 OTs
# Filtered 2 OTs
# Filtered 5 OTs
# Filtered 6 OTs
# Filtered 6 OTs
# Filtered 2 OTs
# Filtered 2 OTs
# Filtered 3 OTs
# Filtered 3 OTs
# Filtered 3 OTs
# Filtered 2 OTs
# hour = 23
# step1 - read OTs
# step2 - convert to gdf
# step3 - temporal aggregation of SPHERA data
# step4 - spatial neighbourhood of SPHERA data
# Filtered 2 OTs
# Filtered 1 OTs
# Filtered 2 OTs
# Filtered 1 OTs
# Filtered 2 OTs
# Filtered 3 OTs
# Filtered 2 OTs
# Filtered 3 OTs
# Filtered 5 OTs
# Filtered 3 OTs
# Filtered 4 OTs
# Filtered 3 OTs
# Filtered 3 OTs
# Filtered 1 OTs
# Filtered 4 OTs
# Filtered 2 OTs
# Filtered 2 OTs
# Filtered 6 OTs
# Filtered 1 OTs
# Filtered 1 OTs
# Filtered 4 OTs
# Filtered 2 OTs
# Filtered 2 OTs
# Filtered 2 OTs
# Filtered 5 OTs
# Filtered 2 OTs
# Filtered 2 OTs
# Filtered 3 OTs
# Filtered 1 OTs
# Filtered 3 OTs
# Filtered 2 OTs
# Filtered 3 OTs
# Filtered 2 OTs
# Filtered 1 OTs
# Filtered 1 OTs
# Filtered 1 OTs
# Filtered 1 OTs
# Filtered 5 OTs
# Filtered 1 OTs
# Filtered 2 OTs
# WRITE EXTERNAL FILE
# 9 2018101 2018-04-11 00:00:00
# hour = 0
# step1 - read OTs
# step2 - convert to gdf
# step3 - temporal aggregation of SPHERA data
# step4 - spatial neighbourhood of SPHERA data
# Filtered 1 OTs
# Filtered 1 OTs
# Filtered 3 OTs
# Filtered 2 OTs
# Filtered 3 OTs
# Filtered 3 OTs
# Filtered 1 OTs
# hour = 1
# step1 - read OTs
# step2 - convert to gdf
# step3 - temporal aggregation of SPHERA data
# step4 - spatial neighbourhood of SPHERA data
# Filtered 1 OTs
# Filtered 1 OTs
# Filtered 2 OTs
# Filtered 2 OTs
# Filtered 1 OTs
# Filtered 2 OTs
# Filtered 8 OTs
# Filtered 2 OTs
# Filtered 2 OTs
# Filtered 1 OTs
# Filtered 1 OTs
# Filtered 1 OTs
# hour = 2
# step1 - read OTs
# step2 - convert to gdf
# step3 - temporal aggregation of SPHERA data
# step4 - spatial neighbourhood of SPHERA data
# Filtered 1 OTs
# hour = 3
# step1 - read OTs
# step2 - convert to gdf
# step3 - temporal aggregation of SPHERA data
# step4 - spatial neighbourhood of SPHERA data
# Filtered 4 OTs
# Filtered 1 OTs
# hour = 4
# step1 - read OTs
# step2 - convert to gdf
# step3 - temporal aggregation of SPHERA data
# step4 - spatial neighbourhood of SPHERA data
# Filtered 6 OTs
# Filtered 2 OTs
# Filtered 1 OTs
# Filtered 1 OTs
# Filtered 2 OTs
# Filtered 3 OTs
# hour = 5
# step1 - read OTs
# hour = 6
# step1 - read OTs
# hour = 7
# step1 - read OTs
# hour = 8
# step1 - read OTs
# hour = 9
# step1 - read OTs
# hour = 10
# step1 - read OTs
# hour = 11
# step1 - read OTs
# hour = 12
# step1 - read OTs
# hour = 13
# step1 - read OTs
# hour = 14
# step1 - read OTs
# step2 - convert to gdf
# step3 - temporal aggregation of SPHERA data
# step4 - spatial neighbourhood of SPHERA data
# Filtered 1 OTs
# Filtered 1 OTs
# Filtered 1 OTs
# hour = 15
# step1 - read OTs
# hour = 16
# step1 - read OTs
# hour = 17
# step1 - read OTs
# step2 - convert to gdf
# step3 - temporal aggregation of SPHERA data
# step4 - spatial neighbourhood of SPHERA data
# Filtered 3 OTs
# Filtered 3 OTs
# hour = 18
# step1 - read OTs
# hour = 19
# step1 - read OTs
# step2 - convert to gdf
# step3 - temporal aggregation of SPHERA data
# step4 - spatial neighbourhood of SPHERA data
# Filtered 2 OTs
# Filtered 5 OTs
# hour = 20
# step1 - read OTs
# step2 - convert to gdf
# step3 - temporal aggregation of SPHERA data
# step4 - spatial neighbourhood of SPHERA data
# Filtered 1 OTs
# Filtered 1 OTs
# Filtered 4 OTs
# Filtered 3 OTs
# hour = 21
# step1 - read OTs
# step2 - convert to gdf
# step3 - temporal aggregation of SPHERA data
# step4 - spatial neighbourhood of SPHERA data
# Filtered 1 OTs
# Filtered 1 OTs
# hour = 22
# step1 - read OTs
# step2 - convert to gdf
# step3 - temporal aggregation of SPHERA data
# step4 - spatial neighbourhood of SPHERA data
# Filtered 1 OTs
# hour = 23
# step1 - read OTs
# step2 - convert to gdf
# step3 - temporal aggregation of SPHERA data
# step4 - spatial neighbourhood of SPHERA data
# Filtered 2 OTs
# Filtered 2 OTs
# Filtered 7 OTs
# Filtered 6 OTs
# Filtered 9 OTs
# WRITE EXTERNAL FILE
# 10 2018102 2018-04-12 00:00:00
# hour = 0
# step1 - read OTs
# step2 - convert to gdf
# step3 - temporal aggregation of SPHERA data
# step4 - spatial neighbourhood of SPHERA data
# Filtered 6 OTs
# Filtered 2 OTs
# Filtered 1 OTs
# Filtered 6 OTs
# Filtered 5 OTs
# Filtered 2 OTs
# Filtered 5 OTs
# Filtered 1 OTs
# hour = 1
# step1 - read OTs
# step2 - convert to gdf
# step3 - temporal aggregation of SPHERA data
# step4 - spatial neighbourhood of SPHERA data
# Filtered 1 OTs
# hour = 2
# step1 - read OTs
# step2 - convert to gdf
# step3 - temporal aggregation of SPHERA data
# step4 - spatial neighbourhood of SPHERA data
# Filtered 1 OTs
# Filtered 2 OTs
# Filtered 2 OTs
# Filtered 2 OTs
# Filtered 1 OTs
# Filtered 1 OTs
# hour = 3
# step1 - read OTs
# step2 - convert to gdf
# step3 - temporal aggregation of SPHERA data
# step4 - spatial neighbourhood of SPHERA data
# Filtered 3 OTs
# Filtered 2 OTs
# Filtered 8 OTs
# Filtered 1 OTs
# Filtered 5 OTs
# Filtered 1 OTs
# Filtered 2 OTs
# hour = 4
# step1 - read OTs
# step2 - convert to gdf
# step3 - temporal aggregation of SPHERA data
# step4 - spatial neighbourhood of SPHERA data
# Filtered 4 OTs
# Filtered 5 OTs
# Filtered 4 OTs
# Filtered 1 OTs
# Filtered 2 OTs
# Filtered 1 OTs
# Filtered 2 OTs
# Filtered 2 OTs
# Filtered 2 OTs
# Filtered 6 OTs
# Filtered 1 OTs
# Filtered 1 OTs
# Filtered 3 OTs
# Filtered 4 OTs
# Filtered 3 OTs
# Filtered 4 OTs
# Filtered 1 OTs
# Filtered 3 OTs
# Filtered 4 OTs
# Filtered 6 OTs
# Filtered 6 OTs
# Filtered 2 OTs
# Filtered 1 OTs
# Filtered 3 OTs
# Filtered 2 OTs
# Filtered 5 OTs
# Filtered 2 OTs
# Filtered 1 OTs
# hour = 5
# step1 - read OTs
# step2 - convert to gdf
# step3 - temporal aggregation of SPHERA data
# step4 - spatial neighbourhood of SPHERA data
# Filtered 1 OTs
# Filtered 4 OTs
# Filtered 5 OTs
# Filtered 5 OTs
# Filtered 1 OTs
# Filtered 1 OTs
# Filtered 1 OTs
# Filtered 2 OTs
# Filtered 3 OTs
# Filtered 3 OTs
# Filtered 1 OTs
# Filtered 1 OTs
# Filtered 3 OTs
# Filtered 6 OTs
# Filtered 1 OTs
# Filtered 1 OTs
# Filtered 4 OTs
# Filtered 1 OTs
# Filtered 1 OTs
# Filtered 2 OTs
# Filtered 5 OTs
# Filtered 2 OTs
# Filtered 4 OTs
# Filtered 1 OTs
# Filtered 8 OTs
# Filtered 3 OTs
# Filtered 3 OTs
# Filtered 2 OTs
# Filtered 2 OTs
# Filtered 2 OTs
# Filtered 1 OTs
# Filtered 3 OTs
# Filtered 3 OTs
# Filtered 1 OTs
# Filtered 3 OTs
# Filtered 1 OTs
# Filtered 4 OTs
# Filtered 2 OTs
# Filtered 1 OTs
# Filtered 1 OTs
# hour = 6
# step1 - read OTs
# step2 - convert to gdf
# step3 - temporal aggregation of SPHERA data
# step4 - spatial neighbourhood of SPHERA data
# Filtered 4 OTs
# Filtered 1 OTs
# Filtered 2 OTs
# Filtered 1 OTs
# Filtered 6 OTs
# Filtered 1 OTs
# Filtered 2 OTs
# Filtered 7 OTs
# Filtered 8 OTs
# Filtered 2 OTs
# Filtered 4 OTs
# Filtered 6 OTs
# Filtered 1 OTs
# Filtered 3 OTs
# Filtered 5 OTs
# Filtered 5 OTs
# Filtered 6 OTs
# Filtered 1 OTs
# Filtered 3 OTs
# Filtered 4 OTs
# Filtered 4 OTs
# Filtered 2 OTs
# Filtered 2 OTs
# Filtered 1 OTs
# Filtered 2 OTs
# Filtered 1 OTs
# Filtered 2 OTs
# Filtered 3 OTs
# Filtered 1 OTs
# Filtered 2 OTs
# Filtered 3 OTs
# Filtered 1 OTs
# hour = 7
# step1 - read OTs
# step2 - convert to gdf
# step3 - temporal aggregation of SPHERA data
# step4 - spatial neighbourhood of SPHERA data
# Filtered 3 OTs
# Filtered 1 OTs
# Filtered 5 OTs
# Filtered 1 OTs
# Filtered 4 OTs
# Filtered 1 OTs
# Filtered 3 OTs
# Filtered 1 OTs
# Filtered 1 OTs
# Filtered 3 OTs
# Filtered 5 OTs
# Filtered 5 OTs
# Filtered 8 OTs
# Filtered 1 OTs
# Filtered 1 OTs
# Filtered 5 OTs
# Filtered 1 OTs
# Filtered 4 OTs
# Filtered 1 OTs
# Filtered 6 OTs
# Filtered 1 OTs
# Filtered 4 OTs
# Filtered 2 OTs
# Filtered 2 OTs
# Filtered 5 OTs
# Filtered 4 OTs
# Filtered 5 OTs
# Filtered 6 OTs
# Filtered 2 OTs
# Filtered 1 OTs
# Filtered 5 OTs
# Filtered 2 OTs
# Filtered 1 OTs
# Filtered 1 OTs
# Filtered 2 OTs
# Filtered 5 OTs
# Filtered 2 OTs
# Filtered 1 OTs
# Filtered 2 OTs
# Filtered 5 OTs
# Filtered 1 OTs
# Filtered 4 OTs
# Filtered 1 OTs
# Filtered 6 OTs
# Filtered 2 OTs
# Filtered 1 OTs
# Filtered 1 OTs
# Filtered 1 OTs
# Filtered 2 OTs
# hour = 8
# step1 - read OTs
# step2 - convert to gdf
# step3 - temporal aggregation of SPHERA data
# step4 - spatial neighbourhood of SPHERA data
# Filtered 1 OTs
# Filtered 1 OTs
# Filtered 1 OTs
# Filtered 3 OTs
# Filtered 1 OTs
# Filtered 6 OTs
# Filtered 1 OTs
# Filtered 7 OTs
# Filtered 2 OTs
# Filtered 2 OTs
# Filtered 1 OTs
# Filtered 1 OTs
# Filtered 8 OTs
# Filtered 3 OTs
# Filtered 1 OTs
# Filtered 2 OTs
# Filtered 2 OTs
# Filtered 1 OTs
# Filtered 1 OTs
# Filtered 3 OTs
# Filtered 3 OTs
# Filtered 1 OTs
# Filtered 3 OTs
# Filtered 1 OTs
# Filtered 3 OTs
# Filtered 2 OTs
# Filtered 3 OTs
# Filtered 2 OTs
# Filtered 6 OTs
# Filtered 2 OTs
# Filtered 1 OTs
# Filtered 2 OTs
# Filtered 4 OTs
# Filtered 4 OTs
# Filtered 6 OTs
# Filtered 2 OTs
# Filtered 1 OTs
# Filtered 3 OTs
# Filtered 1 OTs
# Filtered 3 OTs
# Filtered 4 OTs
# Filtered 1 OTs
# Filtered 1 OTs
# Filtered 6 OTs
# Filtered 2 OTs
# Filtered 2 OTs
# Filtered 1 OTs
# Filtered 2 OTs
# Filtered 1 OTs
# Filtered 1 OTs
# Filtered 1 OTs
# hour = 9
# step1 - read OTs
# step2 - convert to gdf
# step3 - temporal aggregation of SPHERA data
# step4 - spatial neighbourhood of SPHERA data
# Filtered 6 OTs
# Filtered 4 OTs
# Filtered 1 OTs
# Filtered 3 OTs
# Filtered 2 OTs
# Filtered 1 OTs
# Filtered 1 OTs
# Filtered 3 OTs
# Filtered 4 OTs
# Filtered 4 OTs
# Filtered 4 OTs
# Filtered 2 OTs
# Filtered 1 OTs
# Filtered 2 OTs
# Filtered 1 OTs
# Filtered 3 OTs
# Filtered 2 OTs
# Filtered 4 OTs
# Filtered 1 OTs
# Filtered 2 OTs
# Filtered 1 OTs
# Filtered 6 OTs
# Filtered 8 OTs
# Filtered 5 OTs
# Filtered 1 OTs
# Filtered 8 OTs
# Filtered 3 OTs
# Filtered 1 OTs
# Filtered 1 OTs
# Filtered 1 OTs
# Filtered 1 OTs
# Filtered 1 OTs
# Filtered 4 OTs
# Filtered 3 OTs
# Filtered 6 OTs
# Filtered 1 OTs
# Filtered 1 OTs
# hour = 10
# step1 - read OTs
# step2 - convert to gdf
# step3 - temporal aggregation of SPHERA data
# step4 - spatial neighbourhood of SPHERA data
# Filtered 2 OTs
# Filtered 1 OTs
# Filtered 7 OTs
# Filtered 1 OTs
# Filtered 1 OTs
# Filtered 2 OTs
# Filtered 3 OTs
# Filtered 1 OTs
# Filtered 2 OTs
# Filtered 1 OTs
# Filtered 2 OTs
# Filtered 1 OTs
# Filtered 1 OTs
# Filtered 4 OTs
# Filtered 1 OTs
# Filtered 4 OTs
# Filtered 2 OTs
# Filtered 2 OTs
# Filtered 1 OTs
# Filtered 2 OTs
# Filtered 1 OTs
# Filtered 2 OTs
# Filtered 1 OTs
# Filtered 7 OTs
# Filtered 2 OTs
# Filtered 4 OTs
# Filtered 1 OTs
# Filtered 3 OTs
# Filtered 1 OTs
# Filtered 5 OTs
# Filtered 3 OTs
# Filtered 2 OTs
# Filtered 1 OTs
# Filtered 1 OTs
# Filtered 1 OTs
# Filtered 1 OTs
# hour = 11
# step1 - read OTs
# step2 - convert to gdf
# step3 - temporal aggregation of SPHERA data
# step4 - spatial neighbourhood of SPHERA data
# Filtered 3 OTs
# Filtered 2 OTs
# Filtered 3 OTs
# Filtered 3 OTs
# Filtered 5 OTs
# Filtered 1 OTs
# Filtered 1 OTs
# Filtered 1 OTs
# Filtered 1 OTs
# Filtered 2 OTs
# Filtered 2 OTs
# hour = 12
# step1 - read OTs
# step2 - convert to gdf
# step3 - temporal aggregation of SPHERA data
# step4 - spatial neighbourhood of SPHERA data
# Filtered 6 OTs
# Filtered 4 OTs
# Filtered 1 OTs
# Filtered 1 OTs
# Filtered 1 OTs
# Filtered 4 OTs
# Filtered 8 OTs
# Filtered 5 OTs
# Filtered 1 OTs
# Filtered 3 OTs
# Filtered 3 OTs
# Filtered 6 OTs
# Filtered 6 OTs
# Filtered 4 OTs
# Filtered 1 OTs
# Filtered 2 OTs
# Filtered 1 OTs
# Filtered 7 OTs
# Filtered 6 OTs
# Filtered 1 OTs
# Filtered 3 OTs
# Filtered 2 OTs
# Filtered 1 OTs
# Filtered 3 OTs
# Filtered 2 OTs
# Filtered 3 OTs
# Filtered 2 OTs
# Filtered 1 OTs
# Filtered 4 OTs
# Filtered 1 OTs
# Filtered 2 OTs
# Filtered 5 OTs
# Filtered 2 OTs
# Filtered 1 OTs
# hour = 13
# step1 - read OTs
# step2 - convert to gdf
# step3 - temporal aggregation of SPHERA data
# step4 - spatial neighbourhood of SPHERA data
# Filtered 4 OTs
# Filtered 2 OTs
# Filtered 3 OTs
# Filtered 2 OTs
# Filtered 1 OTs
# Filtered 3 OTs
# Filtered 2 OTs
# Filtered 5 OTs
# hour = 14
# step1 - read OTs
# step2 - convert to gdf
# step3 - temporal aggregation of SPHERA data
# step4 - spatial neighbourhood of SPHERA data
# Filtered 1 OTs
# Filtered 1 OTs
# Filtered 2 OTs
# Filtered 3 OTs
# Filtered 6 OTs
# Filtered 1 OTs
# hour = 15
# step1 - read OTs
# step2 - convert to gdf
# step3 - temporal aggregation of SPHERA data
# step4 - spatial neighbourhood of SPHERA data
# Filtered 1 OTs
# Filtered 2 OTs
# Filtered 2 OTs
# Filtered 3 OTs
# Filtered 6 OTs
# Filtered 1 OTs
# Filtered 2 OTs
# hour = 16
# step1 - read OTs
# step2 - convert to gdf
# step3 - temporal aggregation of SPHERA data
# step4 - spatial neighbourhood of SPHERA data
# Filtered 1 OTs
# Filtered 1 OTs
# Filtered 1 OTs
# Filtered 3 OTs
# Filtered 7 OTs
# Filtered 2 OTs
# Filtered 3 OTs
# Filtered 1 OTs
# Filtered 1 OTs
# Filtered 1 OTs
# hour = 17
# step1 - read OTs
# step2 - convert to gdf
# step3 - temporal aggregation of SPHERA data
# step4 - spatial neighbourhood of SPHERA data
# Filtered 2 OTs
# Filtered 1 OTs
# Filtered 3 OTs
# Filtered 5 OTs
# Filtered 6 OTs
# Filtered 3 OTs
# Filtered 1 OTs
# Filtered 3 OTs
# Filtered 3 OTs
# Filtered 2 OTs
# Filtered 1 OTs
# Filtered 4 OTs
# Filtered 1 OTs
# Filtered 2 OTs
# Filtered 2 OTs
# Filtered 1 OTs
# Filtered 2 OTs
# Filtered 1 OTs
# Filtered 1 OTs
# Filtered 1 OTs
# Filtered 1 OTs
# Filtered 1 OTs
# Filtered 2 OTs
# Filtered 3 OTs
# Filtered 5 OTs
# Filtered 2 OTs
# Filtered 2 OTs
# Filtered 1 OTs
# Filtered 6 OTs
# Filtered 3 OTs
# Filtered 3 OTs
# Filtered 1 OTs
# Filtered 1 OTs
# Filtered 3 OTs
# Filtered 2 OTs
# Filtered 3 OTs
# Filtered 3 OTs
# Filtered 1 OTs
# Filtered 1 OTs
# Filtered 1 OTs
# Filtered 1 OTs
# Filtered 1 OTs
# hour = 18
# step1 - read OTs
# step2 - convert to gdf
# step3 - temporal aggregation of SPHERA data
# step4 - spatial neighbourhood of SPHERA data
# Filtered 4 OTs
# Filtered 4 OTs
# Filtered 2 OTs
# Filtered 3 OTs
# Filtered 2 OTs
# Filtered 3 OTs
# Filtered 1 OTs
# Filtered 2 OTs
# Filtered 1 OTs
# Filtered 4 OTs
# Filtered 2 OTs
# Filtered 2 OTs
# Filtered 3 OTs
# Filtered 2 OTs
# Filtered 1 OTs
# Filtered 3 OTs
# Filtered 4 OTs
# Filtered 4 OTs
# Filtered 1 OTs
# Filtered 2 OTs
# Filtered 1 OTs
# Filtered 2 OTs
# Filtered 2 OTs
# Filtered 2 OTs
# hour = 19
# step1 - read OTs
# step2 - convert to gdf
# step3 - temporal aggregation of SPHERA data
# step4 - spatial neighbourhood of SPHERA data
# Filtered 3 OTs
# Filtered 6 OTs
# Filtered 5 OTs
# Filtered 1 OTs
# Filtered 1 OTs
# Filtered 6 OTs
# Filtered 1 OTs
# Filtered 2 OTs
# Filtered 3 OTs
# Filtered 2 OTs
# Filtered 3 OTs
# Filtered 1 OTs
# Filtered 1 OTs
# Filtered 7 OTs
# Filtered 2 OTs
# Filtered 2 OTs
# Filtered 3 OTs
# Filtered 3 OTs
# hour = 20
# step1 - read OTs
# step2 - convert to gdf
# step3 - temporal aggregation of SPHERA data
# step4 - spatial neighbourhood of SPHERA data
# Filtered 2 OTs
# Filtered 1 OTs
# Filtered 2 OTs
# Filtered 4 OTs
# hour = 21
# step1 - read OTs
# hour = 22
# step1 - read OTs
# hour = 23
# step1 - read OTs
# WRITE EXTERNAL FILE
# 11 2018103 2018-04-13 00:00:00
# hour = 0
# step1 - read OTs
# hour = 1
# step1 - read OTs
# step2 - convert to gdf
# step3 - temporal aggregation of SPHERA data
# step4 - spatial neighbourhood of SPHERA data
# Filtered 1 OTs
# hour = 2
# step1 - read OTs
# step2 - convert to gdf
# step3 - temporal aggregation of SPHERA data
# step4 - spatial neighbourhood of SPHERA data
# Filtered 3 OTs
# hour = 3
# step1 - read OTs
# hour = 4
# step1 - read OTs
# hour = 5
# step1 - read OTs
# hour = 6
# step1 - read OTs
# hour = 7
# step1 - read OTs
# hour = 8
# step1 - read OTs
# hour = 9
# step1 - read OTs
# hour = 10
# step1 - read OTs
# hour = 11
# step1 - read OTs
# hour = 12
# step1 - read OTs
# hour = 13
# step1 - read OTs
# hour = 14
# step1 - read OTs
# hour = 15
# step1 - read OTs
# hour = 16
# step1 - read OTs
# hour = 17
# step1 - read OTs
# hour = 18
# step1 - read OTs
# hour = 19
# step1 - read OTs
# hour = 20
# step1 - read OTs
# hour = 21
# step1 - read OTs
# hour = 22
# step1 - read OTs
# hour = 23
# step1 - read OTs
# WRITE EXTERNAL FILE
# 12 2018104 2018-04-14 00:00:00
# hour = 0
# step1 - read OTs
# hour = 1
# step1 - read OTs
# step2 - convert to gdf
# step3 - temporal aggregation of SPHERA data
# step4 - spatial neighbourhood of SPHERA data
# Filtered 2 OTs
# Filtered 1 OTs
# Filtered 1 OTs
# Filtered 3 OTs
# Filtered 3 OTs
# hour = 2
# step1 - read OTs
# step2 - convert to gdf
# step3 - temporal aggregation of SPHERA data
# step4 - spatial neighbourhood of SPHERA data
# Filtered 1 OTs
# Filtered 1 OTs
# hour = 3
# step1 - read OTs
# hour = 4
# step1 - read OTs
# step2 - convert to gdf
# step3 - temporal aggregation of SPHERA data
# step4 - spatial neighbourhood of SPHERA data
# Filtered 5 OTs
# Filtered 4 OTs
# Filtered 2 OTs
# Filtered 3 OTs
# Filtered 1 OTs
# Filtered 2 OTs
# Filtered 1 OTs
# Filtered 8 OTs
# Filtered 1 OTs
# Filtered 3 OTs
# Filtered 2 OTs
# Filtered 7 OTs
# Filtered 6 OTs
# hour = 5
# step1 - read OTs
# step2 - convert to gdf
# step3 - temporal aggregation of SPHERA data
# step4 - spatial neighbourhood of SPHERA data
# Filtered 2 OTs
# Filtered 8 OTs
# Filtered 1 OTs
# Filtered 3 OTs
# Filtered 5 OTs
# Filtered 5 OTs
# Filtered 2 OTs
# Filtered 2 OTs
# Filtered 1 OTs
# Filtered 1 OTs
# Filtered 2 OTs
# Filtered 2 OTs
# Filtered 2 OTs
# Filtered 4 OTs
# Filtered 1 OTs
# Filtered 1 OTs
# Filtered 3 OTs
# Filtered 4 OTs
# Filtered 1 OTs
# Filtered 2 OTs
# Filtered 1 OTs
# Filtered 6 OTs
# Filtered 3 OTs
# Filtered 2 OTs
# Filtered 1 OTs
# Filtered 1 OTs
# Filtered 1 OTs
# Filtered 7 OTs
# Filtered 4 OTs
# Filtered 8 OTs
# Filtered 2 OTs
# Filtered 1 OTs
# Filtered 1 OTs
# Filtered 1 OTs
# hour = 6
# step1 - read OTs
# step2 - convert to gdf
# step3 - temporal aggregation of SPHERA data
# step4 - spatial neighbourhood of SPHERA data
# Filtered 5 OTs
# Filtered 1 OTs
# Filtered 3 OTs
# Filtered 2 OTs
# Filtered 3 OTs
# Filtered 3 OTs
# Filtered 1 OTs
# Filtered 2 OTs
# Filtered 1 OTs
# Filtered 1 OTs
# Filtered 5 OTs
# Filtered 2 OTs
# Filtered 1 OTs
# Filtered 6 OTs
# Filtered 4 OTs
# Filtered 2 OTs
# Filtered 1 OTs
# Filtered 1 OTs
# Filtered 4 OTs
# Filtered 2 OTs
# Filtered 2 OTs
# Filtered 2 OTs
# Filtered 2 OTs
# Filtered 5 OTs
# Filtered 6 OTs
# Filtered 2 OTs
# Filtered 1 OTs
# Filtered 6 OTs
# Filtered 2 OTs
# Filtered 1 OTs
# Filtered 2 OTs
# Filtered 8 OTs
# Filtered 2 OTs
# Filtered 3 OTs
# Filtered 1 OTs
# Filtered 2 OTs
# Filtered 7 OTs
# Filtered 3 OTs
# Filtered 6 OTs
# Filtered 1 OTs
# Filtered 1 OTs
# hour = 7
# step1 - read OTs
# step2 - convert to gdf
# step3 - temporal aggregation of SPHERA data
# step4 - spatial neighbourhood of SPHERA data
# Filtered 7 OTs
# Filtered 3 OTs
# Filtered 6 OTs
# Filtered 3 OTs
# Filtered 2 OTs
# Filtered 3 OTs
# Filtered 4 OTs
# Filtered 1 OTs
# Filtered 2 OTs
# Filtered 3 OTs
# Filtered 4 OTs
# Filtered 1 OTs
# Filtered 4 OTs
# Filtered 2 OTs
# Filtered 4 OTs
# Filtered 1 OTs
# Filtered 1 OTs
# Filtered 4 OTs
# Filtered 2 OTs
# Filtered 3 OTs
# Filtered 6 OTs
# Filtered 5 OTs
# Filtered 2 OTs
# Filtered 5 OTs
# Filtered 5 OTs
# Filtered 1 OTs
# Filtered 5 OTs
# Filtered 2 OTs
# Filtered 4 OTs
# Filtered 4 OTs
# Filtered 1 OTs
# Filtered 1 OTs
# Filtered 1 OTs
# Filtered 2 OTs
# Filtered 2 OTs
# Filtered 2 OTs
# Filtered 2 OTs
# Filtered 2 OTs
# Filtered 6 OTs
# Filtered 3 OTs
# Filtered 2 OTs
# Filtered 1 OTs
# Filtered 6 OTs
# Filtered 6 OTs
# Filtered 2 OTs
# Filtered 4 OTs
# Filtered 3 OTs
# Filtered 1 OTs
# Filtered 2 OTs
# hour = 8
# step1 - read OTs
# step2 - convert to gdf
# step3 - temporal aggregation of SPHERA data
# step4 - spatial neighbourhood of SPHERA data
# Filtered 4 OTs
# Filtered 3 OTs
# Filtered 5 OTs
# Filtered 2 OTs
# Filtered 1 OTs
# Filtered 3 OTs
# Filtered 3 OTs
# Filtered 6 OTs
# Filtered 4 OTs
# Filtered 1 OTs
# Filtered 2 OTs
# Filtered 2 OTs
# Filtered 7 OTs
# Filtered 1 OTs
# Filtered 1 OTs
# Filtered 2 OTs
# Filtered 5 OTs
# Filtered 6 OTs
# Filtered 5 OTs
# Filtered 4 OTs
# Filtered 4 OTs
# Filtered 4 OTs
# Filtered 1 OTs
# Filtered 2 OTs
# Filtered 4 OTs
# Filtered 4 OTs
# Filtered 2 OTs
# Filtered 1 OTs
# Filtered 1 OTs
# Filtered 1 OTs
# Filtered 1 OTs
# Filtered 1 OTs
# hour = 9
# step1 - read OTs
# step2 - convert to gdf
# step3 - temporal aggregation of SPHERA data
# step4 - spatial neighbourhood of SPHERA data
# Filtered 2 OTs
# Filtered 3 OTs
# Filtered 7 OTs
# Filtered 1 OTs
# Filtered 1 OTs
# Filtered 4 OTs
# Filtered 8 OTs
# Filtered 1 OTs
# Filtered 2 OTs
# Filtered 1 OTs
# Filtered 3 OTs
# Filtered 3 OTs
# Filtered 1 OTs
# Filtered 2 OTs
# Filtered 4 OTs
# Filtered 1 OTs
# Filtered 3 OTs
# Filtered 1 OTs
# Filtered 3 OTs
# Filtered 1 OTs
# Filtered 1 OTs
# Filtered 1 OTs
# Filtered 6 OTs
# Filtered 2 OTs
# Filtered 3 OTs
# Filtered 3 OTs
# Filtered 1 OTs
# Filtered 2 OTs
# Filtered 2 OTs
# hour = 10
# step1 - read OTs
# step2 - convert to gdf
# step3 - temporal aggregation of SPHERA data
# step4 - spatial neighbourhood of SPHERA data
# Filtered 1 OTs
# Filtered 1 OTs
# Filtered 5 OTs
# Filtered 1 OTs
# Filtered 4 OTs
# Filtered 3 OTs
# Filtered 1 OTs
# Filtered 1 OTs
# Filtered 1 OTs
# Filtered 3 OTs
# Filtered 1 OTs
# Filtered 5 OTs
# Filtered 3 OTs
# Filtered 2 OTs
# hour = 11
# step1 - read OTs
# step2 - convert to gdf
# step3 - temporal aggregation of SPHERA data
# step4 - spatial neighbourhood of SPHERA data
# Filtered 1 OTs
# Filtered 4 OTs
# Filtered 2 OTs
# Filtered 1 OTs
# Filtered 6 OTs
# Filtered 4 OTs
# Filtered 1 OTs
# Filtered 2 OTs
# Filtered 2 OTs
# Filtered 3 OTs
# Filtered 2 OTs
# Filtered 2 OTs
# hour = 12
# step1 - read OTs
# step2 - convert to gdf
# step3 - temporal aggregation of SPHERA data
# step4 - spatial neighbourhood of SPHERA data
# Filtered 2 OTs
# Filtered 2 OTs
# Filtered 1 OTs
# Filtered 1 OTs
# Filtered 2 OTs
# Filtered 1 OTs
# hour = 13
# step1 - read OTs
# step2 - convert to gdf
# step3 - temporal aggregation of SPHERA data
# step4 - spatial neighbourhood of SPHERA data
# 2 OTs kept!
# 1 OTs kept!
# hour = 14
# step1 - read OTs
# step2 - convert to gdf
# step3 - temporal aggregation of SPHERA data
# step4 - spatial neighbourhood of SPHERA data
# Filtered 2 OTs
# Filtered 4 OTs
# Filtered 2 OTs
# Filtered 1 OTs
# Filtered 1 OTs
# Filtered 4 OTs
# Filtered 1 OTs
# Filtered 1 OTs
# Filtered 1 OTs
# 3 OTs kept!
# 1 OTs kept!
# 4 OTs kept!
# 2 OTs kept!
# 1 OTs kept!
# 3 OTs kept!
# 5 OTs kept!
# 1 OTs kept!
# 6 OTs kept!
# 2 OTs kept!
# 4 OTs kept!
# 2 OTs kept!
# hour = 15
# step1 - read OTs
# step2 - convert to gdf
# step3 - temporal aggregation of SPHERA data
# step4 - spatial neighbourhood of SPHERA data
# Filtered 6 OTs
# Filtered 3 OTs
# Filtered 4 OTs
# Filtered 2 OTs
# Filtered 1 OTs
# Filtered 1 OTs
# Filtered 5 OTs
# Filtered 2 OTs
# Filtered 1 OTs
# Filtered 4 OTs
# Filtered 1 OTs
# Filtered 2 OTs
# Filtered 3 OTs
# Filtered 1 OTs
# Filtered 3 OTs
# 1 OTs kept!
# 5 OTs kept!
# 8 OTs kept!
# 3 OTs kept!
# 5 OTs kept!
# 4 OTs kept!
# 3 OTs kept!
# 1 OTs kept!
# 2 OTs kept!
# 6 OTs kept!
# 6 OTs kept!
# 1 OTs kept!
# 3 OTs kept!
# 2 OTs kept!
# 2 OTs kept!
# 2 OTs kept!
# Filtered 6 OTs
# 4 OTs kept!
# 4 OTs kept!
# 4 OTs kept!
# 3 OTs kept!
# 8 OTs kept!
# 2 OTs kept!
# 2 OTs kept!
# 2 OTs kept!
# 1 OTs kept!
# hour = 16
# step1 - read OTs
# step2 - convert to gdf
# step3 - temporal aggregation of SPHERA data
# step4 - spatial neighbourhood of SPHERA data
# 9 OTs kept!
# 6 OTs kept!
# 2 OTs kept!
# 6 OTs kept!
# 2 OTs kept!
# 1 OTs kept!
# 1 OTs kept!
# 2 OTs kept!
# 4 OTs kept!
# 5 OTs kept!
# 9 OTs kept!
# 6 OTs kept!
# 5 OTs kept!
# 3 OTs kept!
# 3 OTs kept!
# 3 OTs kept!
# 1 OTs kept!
# 1 OTs kept!
# 1 OTs kept!
# 1 OTs kept!
# 1 OTs kept!
# 6 OTs kept!
# 1 OTs kept!
# 1 OTs kept!
# 1 OTs kept!
# 2 OTs kept!
# 6 OTs kept!
# 2 OTs kept!
# 3 OTs kept!
# 4 OTs kept!
# 2 OTs kept!
# 1 OTs kept!
# 6 OTs kept!
# 3 OTs kept!
# 2 OTs kept!
# 3 OTs kept!
# 2 OTs kept!
# 6 OTs kept!
# 6 OTs kept!
# 1 OTs kept!
# 3 OTs kept!
# 6 OTs kept!
# 3 OTs kept!
# 1 OTs kept!
# 5 OTs kept!
# 2 OTs kept!
# hour = 17
# step1 - read OTs
# step2 - convert to gdf
# step3 - temporal aggregation of SPHERA data
# step4 - spatial neighbourhood of SPHERA data
# 2 OTs kept!
# 6 OTs kept!
# 6 OTs kept!
# 5 OTs kept!
# 7 OTs kept!
# 6 OTs kept!
# 5 OTs kept!
# 3 OTs kept!
# 1 OTs kept!
# 2 OTs kept!
# 4 OTs kept!
# 8 OTs kept!
# 7 OTs kept!
# 2 OTs kept!
# 9 OTs kept!
# 1 OTs kept!
# 8 OTs kept!
# 8 OTs kept!
# 1 OTs kept!
# 1 OTs kept!
# 1 OTs kept!
# 4 OTs kept!
# 4 OTs kept!
# 2 OTs kept!
# 5 OTs kept!
# 1 OTs kept!
# 3 OTs kept!
# 8 OTs kept!
# 1 OTs kept!
# 8 OTs kept!
# 4 OTs kept!
# 5 OTs kept!
# 4 OTs kept!
# 3 OTs kept!
# 1 OTs kept!
# 5 OTs kept!
# 5 OTs kept!
# 1 OTs kept!
# 3 OTs kept!
# 5 OTs kept!
# 3 OTs kept!
# 2 OTs kept!
# 3 OTs kept!
# 2 OTs kept!
# 1 OTs kept!
# 1 OTs kept!
# 1 OTs kept!
# 4 OTs kept!
# 1 OTs kept!
# 9 OTs kept!
# 3 OTs kept!
# 2 OTs kept!
# hour = 18
# step1 - read OTs
# step2 - convert to gdf
# step3 - temporal aggregation of SPHERA data
# step4 - spatial neighbourhood of SPHERA data
# Filtered 1 OTs
# 2 OTs kept!
# 3 OTs kept!
# 4 OTs kept!
# 9 OTs kept!
# 5 OTs kept!
# 1 OTs kept!
# 6 OTs kept!
# 7 OTs kept!
# 3 OTs kept!
# 1 OTs kept!
# 1 OTs kept!
# 2 OTs kept!
# 9 OTs kept!
# 8 OTs kept!
# 3 OTs kept!
# 4 OTs kept!
# 4 OTs kept!
# 5 OTs kept!
# 1 OTs kept!
# 2 OTs kept!
# 3 OTs kept!
# 2 OTs kept!
# 1 OTs kept!
# 2 OTs kept!
# 5 OTs kept!
# 2 OTs kept!
# 2 OTs kept!
# 1 OTs kept!
# 1 OTs kept!
# 2 OTs kept!
# Filtered 1 OTs
# 6 OTs kept!
# 8 OTs kept!
# Filtered 1 OTs
# 2 OTs kept!
# 8 OTs kept!
# 6 OTs kept!
# 6 OTs kept!
# 2 OTs kept!
# 1 OTs kept!
# 4 OTs kept!
# 7 OTs kept!
# 1 OTs kept!
# Filtered 2 OTs
# 1 OTs kept!
# 1 OTs kept!
# hour = 19
# step1 - read OTs
# step2 - convert to gdf
# step3 - temporal aggregation of SPHERA data
# step4 - spatial neighbourhood of SPHERA data
# Filtered 1 OTs
# Filtered 1 OTs
# Filtered 1 OTs
# 4 OTs kept!
# 2 OTs kept!
# 2 OTs kept!
# 1 OTs kept!
# 1 OTs kept!
# 4 OTs kept!
# 2 OTs kept!
# 1 OTs kept!
# 1 OTs kept!
# 1 OTs kept!
# 4 OTs kept!
# 1 OTs kept!
# 1 OTs kept!
# 8 OTs kept!
# 4 OTs kept!
# 6 OTs kept!
# 4 OTs kept!
# 2 OTs kept!
# 8 OTs kept!
# 4 OTs kept!
# 1 OTs kept!
# Filtered 5 OTs
# Filtered 2 OTs
# Filtered 7 OTs
# Filtered 2 OTs
# Filtered 4 OTs
# hour = 20
# step1 - read OTs
# hour = 21
# step1 - read OTs
# step2 - convert to gdf
# step3 - temporal aggregation of SPHERA data
# step4 - spatial neighbourhood of SPHERA data
# Filtered 2 OTs
# hour = 22
# step1 - read OTs
# step2 - convert to gdf
# step3 - temporal aggregation of SPHERA data
# step4 - spatial neighbourhood of SPHERA data
# Filtered 1 OTs
# hour = 23
# step1 - read OTs
# step2 - convert to gdf
# step3 - temporal aggregation of SPHERA data
# step4 - spatial neighbourhood of SPHERA data
# Filtered 1 OTs
# Filtered 2 OTs
# Filtered 2 OTs
# WRITE EXTERNAL FILE
# 13 2018105 2018-04-15 00:00:00
# hour = 0
# step1 - read OTs
# hour = 1
# step1 - read OTs
# hour = 2
# step1 - read OTs
# step2 - convert to gdf
# step3 - temporal aggregation of SPHERA data
# step4 - spatial neighbourhood of SPHERA data
# Filtered 1 OTs
# Filtered 1 OTs
# Filtered 1 OTs
# Filtered 1 OTs
# Filtered 1 OTs
# hour = 3
# step1 - read OTs
# step2 - convert to gdf
# step3 - temporal aggregation of SPHERA data
# step4 - spatial neighbourhood of SPHERA data
# Filtered 2 OTs
# Filtered 1 OTs
# hour = 4
# step1 - read OTs
# step2 - convert to gdf
# step3 - temporal aggregation of SPHERA data
# step4 - spatial neighbourhood of SPHERA data
# Filtered 2 OTs
# Filtered 4 OTs
# Filtered 2 OTs
# Filtered 3 OTs
# Filtered 1 OTs
# Filtered 1 OTs
# Filtered 1 OTs
# Filtered 3 OTs
# hour = 5
# step1 - read OTs
# step2 - convert to gdf
# step3 - temporal aggregation of SPHERA data
# step4 - spatial neighbourhood of SPHERA data
# Filtered 1 OTs
# Filtered 1 OTs
# Filtered 3 OTs
# Filtered 1 OTs
# hour = 6
# step1 - read OTs
# hour = 7
# step1 - read OTs
# hour = 8
# step1 - read OTs
# hour = 9
# step1 - read OTs
# step2 - convert to gdf
# step3 - temporal aggregation of SPHERA data
# step4 - spatial neighbourhood of SPHERA data
# Filtered 1 OTs
# Filtered 4 OTs
# hour = 10
# step1 - read OTs
# step2 - convert to gdf
# step3 - temporal aggregation of SPHERA data
# step4 - spatial neighbourhood of SPHERA data
# 3 OTs kept!
# hour = 11
# step1 - read OTs
# step2 - convert to gdf
# step3 - temporal aggregation of SPHERA data
# step4 - spatial neighbourhood of SPHERA data
# 4 OTs kept!
# 1 OTs kept!
# hour = 12
# step1 - read OTs
# step2 - convert to gdf
# step3 - temporal aggregation of SPHERA data
# step4 - spatial neighbourhood of SPHERA data
# Filtered 2 OTs
# Filtered 1 OTs
# Filtered 2 OTs
# Filtered 5 OTs
# Filtered 2 OTs
# Filtered 2 OTs
# Filtered 5 OTs
# 2 OTs kept!
# 2 OTs kept!
# hour = 13
# step1 - read OTs
# hour = 14
# step1 - read OTs
# step2 - convert to gdf
# step3 - temporal aggregation of SPHERA data
# step4 - spatial neighbourhood of SPHERA data
# 2 OTs kept!
# 1 OTs kept!
# 3 OTs kept!
# 3 OTs kept!
# hour = 15
# step1 - read OTs
# hour = 16
# step1 - read OTs
# step2 - convert to gdf
# step3 - temporal aggregation of SPHERA data
# step4 - spatial neighbourhood of SPHERA data
# 5 OTs kept!
# 2 OTs kept!
# hour = 17
# step1 - read OTs
# step2 - convert to gdf
# step3 - temporal aggregation of SPHERA data
# step4 - spatial neighbourhood of SPHERA data
# Filtered 5 OTs
# Filtered 5 OTs
# Filtered 1 OTs
# 2 OTs kept!
# 4 OTs kept!
# Filtered 1 OTs
# Filtered 6 OTs
# hour = 18
# step1 - read OTs
# step2 - convert to gdf
# step3 - temporal aggregation of SPHERA data
# step4 - spatial neighbourhood of SPHERA data
# Filtered 4 OTs
# Filtered 2 OTs
# Filtered 2 OTs
# Filtered 5 OTs
# Filtered 4 OTs
# Filtered 6 OTs
# 4 OTs kept!
# 5 OTs kept!
# 1 OTs kept!
# hour = 19
# step1 - read OTs
# step2 - convert to gdf
# step3 - temporal aggregation of SPHERA data
# step4 - spatial neighbourhood of SPHERA data
# Filtered 9 OTs
# Filtered 3 OTs
# 6 OTs kept!
# 8 OTs kept!
# Filtered 1 OTs
# 2 OTs kept!
# hour = 20
# step1 - read OTs
# step2 - convert to gdf
# step3 - temporal aggregation of SPHERA data
# step4 - spatial neighbourhood of SPHERA data
# Filtered 2 OTs
# hour = 21
# step1 - read OTs
# hour = 22
# step1 - read OTs
# step2 - convert to gdf
# step3 - temporal aggregation of SPHERA data
# step4 - spatial neighbourhood of SPHERA data
# 1 OTs kept!
# 1 OTs kept!
# hour = 23
# step1 - read OTs
# step2 - convert to gdf
# step3 - temporal aggregation of SPHERA data
# step4 - spatial neighbourhood of SPHERA data
# 1 OTs kept!
# 5 OTs kept!
# 2 OTs kept!
# 2 OTs kept!
# WRITE EXTERNAL FILE
# 14 2018106 2018-04-16 00:00:00
# hour = 0
# step1 - read OTs
# hour = 1
# step1 - read OTs
# hour = 2
# step1 - read OTs
# hour = 3
# step1 - read OTs
# hour = 4
# step1 - read OTs
# hour = 5
# step1 - read OTs
# hour = 6
# step1 - read OTs
# hour = 7
# step1 - read OTs
# hour = 8
# step1 - read OTs
# hour = 9
# step1 - read OTs
# hour = 10
# step1 - read OTs
# hour = 11
# step1 - read OTs
# hour = 12
# step1 - read OTs
# hour = 13
# step1 - read OTs
# step2 - convert to gdf
# step3 - temporal aggregation of SPHERA data
# step4 - spatial neighbourhood of SPHERA data
# 2 OTs kept!
# 6 OTs kept!
# 1 OTs kept!
# 2 OTs kept!
# 5 OTs kept!
# hour = 14
# step1 - read OTs
# step2 - convert to gdf
# step3 - temporal aggregation of SPHERA data
# step4 - spatial neighbourhood of SPHERA data
# 1 OTs kept!
# 1 OTs kept!
# 9 OTs kept!
# 3 OTs kept!
# 3 OTs kept!
# 1 OTs kept!
# 3 OTs kept!
# 2 OTs kept!
# Filtered 4 OTs
# Filtered 1 OTs
# Filtered 2 OTs
# Filtered 1 OTs
# Filtered 1 OTs
# Filtered 1 OTs
# 6 OTs kept!
# 2 OTs kept!
# 2 OTs kept!
# 1 OTs kept!
# 1 OTs kept!
# hour = 15
# step1 - read OTs
# step2 - convert to gdf
# step3 - temporal aggregation of SPHERA data
# step4 - spatial neighbourhood of SPHERA data
# 1 OTs kept!
# 2 OTs kept!
# Filtered 3 OTs
# Filtered 1 OTs
# 1 OTs kept!
# 2 OTs kept!
# 1 OTs kept!
# Filtered 8 OTs
# Filtered 5 OTs
# 1 OTs kept!
# 6 OTs kept!
# 2 OTs kept!
# 4 OTs kept!
# 4 OTs kept!
# 1 OTs kept!
# 1 OTs kept!
# 2 OTs kept!
# 2 OTs kept!
# hour = 16
# step1 - read OTs
# step2 - convert to gdf
# step3 - temporal aggregation of SPHERA data
# step4 - spatial neighbourhood of SPHERA data
# 4 OTs kept!
# Filtered 2 OTs
# Filtered 4 OTs
# Filtered 6 OTs
# Filtered 3 OTs
# 2 OTs kept!
# Filtered 1 OTs
# 3 OTs kept!
# 2 OTs kept!
# 1 OTs kept!
# hour = 17
# step1 - read OTs
# step2 - convert to gdf
# step3 - temporal aggregation of SPHERA data
# step4 - spatial neighbourhood of SPHERA data
# Filtered 6 OTs
# Filtered 4 OTs
# Filtered 1 OTs
# Filtered 3 OTs
# 2 OTs kept!
# 6 OTs kept!
# 9 OTs kept!
# 3 OTs kept!
# 4 OTs kept!
# 2 OTs kept!
# 2 OTs kept!
# 4 OTs kept!
# 1 OTs kept!
# 1 OTs kept!
# 2 OTs kept!
# 2 OTs kept!
# 1 OTs kept!
# 1 OTs kept!
# 3 OTs kept!
# hour = 18
# step1 - read OTs
# step2 - convert to gdf
# step3 - temporal aggregation of SPHERA data
# step4 - spatial neighbourhood of SPHERA data
# 5 OTs kept!
# 1 OTs kept!
# 1 OTs kept!
# 1 OTs kept!
# 1 OTs kept!
# 1 OTs kept!
# hour = 19
# step1 - read OTs
# step2 - convert to gdf
# step3 - temporal aggregation of SPHERA data
# step4 - spatial neighbourhood of SPHERA data
# Filtered 1 OTs
# Filtered 1 OTs
# Filtered 4 OTs
# Filtered 1 OTs
# Filtered 1 OTs
# 3 OTs kept!
# 4 OTs kept!
# 6 OTs kept!
# hour = 20
# step1 - read OTs
# step2 - convert to gdf
# step3 - temporal aggregation of SPHERA data
# step4 - spatial neighbourhood of SPHERA data
# Filtered 4 OTs
# Filtered 1 OTs
# 6 OTs kept!
# 1 OTs kept!
# hour = 21
# step1 - read OTs
# hour = 22
# step1 - read OTs
# hour = 23
# step1 - read OTs
# WRITE EXTERNAL FILE
# 15 2018107 2018-04-17 00:00:00
# hour = 0
# step1 - read OTs
# step2 - convert to gdf
# step3 - temporal aggregation of SPHERA data
# step4 - spatial neighbourhood of SPHERA data
# Filtered 3 OTs
# Filtered 3 OTs
# hour = 1
# step1 - read OTs
# step2 - convert to gdf
# step3 - temporal aggregation of SPHERA data
# step4 - spatial neighbourhood of SPHERA data
# Filtered 2 OTs
# Filtered 1 OTs
# hour = 2
# step1 - read OTs
# step2 - convert to gdf
# step3 - temporal aggregation of SPHERA data
# step4 - spatial neighbourhood of SPHERA data
# Filtered 2 OTs
# hour = 3
# step1 - read OTs
# hour = 4
# step1 - read OTs
# hour = 5
# step1 - read OTs
# hour = 6
# step1 - read OTs
# hour = 7
# step1 - read OTs
# hour = 8
# step1 - read OTs
# hour = 9
# step1 - read OTs
# hour = 10
# step1 - read OTs
# hour = 11
# step1 - read OTs
# hour = 12
# step1 - read OTs
# step2 - convert to gdf
# step3 - temporal aggregation of SPHERA data
# step4 - spatial neighbourhood of SPHERA data
# Filtered 2 OTs
# Filtered 2 OTs
# Filtered 1 OTs
# Filtered 1 OTs
# Filtered 4 OTs
# Filtered 1 OTs
# Filtered 2 OTs
# Filtered 2 OTs
# Filtered 1 OTs
# Filtered 2 OTs
# hour = 13
# step1 - read OTs
# step2 - convert to gdf
# step3 - temporal aggregation of SPHERA data
# step4 - spatial neighbourhood of SPHERA data
# Filtered 1 OTs
# Filtered 2 OTs
# Filtered 5 OTs
# Filtered 6 OTs
# Filtered 2 OTs
# Filtered 3 OTs
# Filtered 8 OTs
# Filtered 1 OTs
# Filtered 2 OTs
# Filtered 2 OTs
# Filtered 3 OTs
# Filtered 1 OTs
# Filtered 1 OTs
# Filtered 1 OTs
# Filtered 4 OTs
# Filtered 2 OTs
# Filtered 2 OTs
# Filtered 2 OTs
# Filtered 7 OTs
# Filtered 4 OTs
# Filtered 2 OTs
# Filtered 2 OTs
# Filtered 3 OTs
# Filtered 7 OTs
# Filtered 2 OTs
# Filtered 4 OTs
# Filtered 1 OTs
# Filtered 1 OTs
# Filtered 2 OTs
# 2 OTs kept!
# hour = 14
# step1 - read OTs
# step2 - convert to gdf
# step3 - temporal aggregation of SPHERA data
# step4 - spatial neighbourhood of SPHERA data
# 1 OTs kept!
# 2 OTs kept!
# Filtered 2 OTs
# Filtered 1 OTs
# Filtered 1 OTs
# Filtered 1 OTs
# Filtered 2 OTs
# Filtered 2 OTs
# Filtered 7 OTs
# Filtered 2 OTs
# hour = 15
# step1 - read OTs
# step2 - convert to gdf
# step3 - temporal aggregation of SPHERA data
# step4 - spatial neighbourhood of SPHERA data
# Filtered 2 OTs
# Filtered 3 OTs
# 1 OTs kept!
# 1 OTs kept!
# hour = 16
# step1 - read OTs
# hour = 17
# step1 - read OTs
# step2 - convert to gdf
# step3 - temporal aggregation of SPHERA data
# step4 - spatial neighbourhood of SPHERA data
# Filtered 2 OTs
# hour = 18
# step1 - read OTs
# hour = 19
# step1 - read OTs
# hour = 20
# step1 - read OTs
# hour = 21
# step1 - read OTs
# hour = 22
# step1 - read OTs
# hour = 23
# step1 - read OTs
# WRITE EXTERNAL FILE
# 16 2018108 2018-04-18 00:00:00
# hour = 0
# step1 - read OTs
# hour = 1
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-21-5db29b33c9dd> in <module>
#      36         print(f'hour = {hh}')
#      37         #read original OT data:
# ---> 38         cpclat, cpclon, otpmax, dtmin, ot_timing = HF.HF_OTdata(day,hh,hh+1,otpref,otdir,othstart)
#      39         print('step1 - read OTs')
#      40
#
# ~/phd/KIT/scripts/HaileventsFunctions.ipynb in HF_OTdata(day, hhmin, hhmax, otpref, otdir, othstart)
#     341     "                                           #latg: 980*1120 long arrays having a unique value of lats in the same array\n",
#     342     "                                           #and progressively increasing value at every array\n",
# --> 343     "    #make copies of the matrix:\n",
#     344     "    cpclon=1.*longg;cpclat=1.*latg;\n",
#     345     "\n",
#
# KeyboardInterrupt:

# %%
day = 2016144

# %%
214-210-3
# Out:
# 1

# %%
#read dictionary from external file
with open(fold + f'data/OT_filtered_data/tempAgg_3h_5-95pThresh/OTfilt_{day}.txt', "rb") as file:  
     OTFILTERED = pickle.load(file)

# %%
OTFILTERED['metadata']
# Out:
#                     hour Filt_OTs Orig_OTs
# 0   2016-04-02T00:00:00Z        0       12
# 1   2016-04-02T01:00:00Z        0      130
# 2   2016-04-02T02:00:00Z        2      344
# 3   2016-04-02T03:00:00Z        0      354
# 4   2016-04-02T04:00:00Z        0      450
# 5   2016-04-02T05:00:00Z        1      259
# 6   2016-04-02T06:00:00Z        0       57
# 7   2016-04-02T07:00:00Z        0        2
# 8   2016-04-02T08:00:00Z        0        1
# 9                    NaN      NaN      NaN
# 10                   NaN      NaN      NaN
# 11                   NaN      NaN      NaN
# 12                   NaN      NaN      NaN
# 13                   NaN      NaN      NaN
# 14                   NaN      NaN      NaN
# 15                   NaN      NaN      NaN
# 16                   NaN      NaN      NaN
# 17                   NaN      NaN      NaN
# 18                   NaN      NaN      NaN
# 19                   NaN      NaN      NaN
# 20                   NaN      NaN      NaN
# 21                   NaN      NaN      NaN
# 22                   NaN      NaN      NaN
# 23                   NaN      NaN      NaN
